# %%
import nibabel as nib
from matplotlib import pyplot as plt
from matplotlib.colors import NoNorm
import numpy as np
# %matplotlib notebook

# %%
import os

# %%
DATA_DIR = '/mnt/DATA/git/Manning/3dmedical/data/small_data/small'

# %%
os.listdir(DATA_DIR)
# Out:
# ['t1', 't2']

# %%
t2_sample_name = 'IXI102-HH-1416-T2_reg_fcm.nii'
t2_data = os.path.join(DATA_DIR, *['t2', t2_sample_name])

t1_sample_name = 'IXI102-HH-1416-T1_fcm.nii'
t1_data = os.path.join(DATA_DIR, *['t1', t1_sample_name])

# %%
t1image_data = nib.load(t1_data).get_data()
t2image_data = nib.load(t2_data).get_data()
# Out:
# /home/theon/.virtualenvs/CV/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """Entry point for launching an IPython kernel.
# /home/theon/.virtualenvs/CV/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0

# %%
t1image_data.shape, t2image_data.shape
# Out:
# ((120, 120, 90), (120, 120, 90))

# %%
slice_number  = 25

t2_slice = t2image_data[:,:, slice_number]
t1_slice = t1image_data[:,:, slice_number]

plt.subplot(1,2,1)
plt.imshow(np.rot90(t1_slice), interpolation='nearest', cmap='gray')
plt.subplot(1,2,2)
plt.imshow(np.rot90(t2_slice), interpolation='nearest', cmap='gray')
plt.savefig('submission.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
