# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os
import re
import string

# %% [markdown]
# # DATA

# %%
df = pd.read_csv('./data/stackexchange_812k.csv', keep_default_na=False)
# Out:
# /home/theon/.virtualenvs/NLP/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    post_id parent_id comment_id  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        6
#
#                                                 text category
# 0                      Eliciting priors from experts    title
# 1                                 What is normality?    title
# 2  What are some valuable Statistical Analysis op...    title
# 3  Assessing the significance of differences in d...    title
# 4  The Two Cultures: statistics vs. machine learn...    title

# %%
df['clean_text'] = df.text.apply(lambda s: s.lower())

# %%
df.head()
# Out:
#    post_id parent_id comment_id  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        6
#
#                                                 text category  \
# 0                      Eliciting priors from experts    title
# 1                                 What is normality?    title
# 2  What are some valuable Statistical Analysis op...    title
# 3  Assessing the significance of differences in d...    title
# 4  The Two Cultures: statistics vs. machine learn...    title
#
#                                           clean_text
# 0                      eliciting priors from experts
# 1                                 what is normality?
# 2  what are some valuable statistical analysis op...
# 3  assessing the significance of differences in d...
# 4  the two cultures: statistics vs. machine learn...

# %% [markdown]
# ## Clean punctuations

# %%
df.clean_text = df.clean_text.str.replace('[{}]'.format(string.punctuation), '')
df.head()
# Out:
#    post_id parent_id comment_id  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        6
#
#                                                 text category  \
# 0                      Eliciting priors from experts    title
# 1                                 What is normality?    title
# 2  What are some valuable Statistical Analysis op...    title
# 3  Assessing the significance of differences in d...    title
# 4  The Two Cultures: statistics vs. machine learn...    title
#
#                                           clean_text
# 0                      eliciting priors from experts
# 1                                  what is normality
# 2  what are some valuable statistical analysis op...
# 3  assessing the significance of differences in d...
# 4    the two cultures statistics vs machine learning

# %% [markdown]
# ## Tokenize

# %%
df.head()
# Out:
#    post_id parent_id comment_id  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        6
#
#                                                 text category  \
# 0                      Eliciting priors from experts    title
# 1                                 What is normality?    title
# 2  What are some valuable Statistical Analysis op...    title
# 3  Assessing the significance of differences in d...    title
# 4  The Two Cultures: statistics vs. machine learn...    title
#
#                                           clean_text
# 0                      eliciting priors from experts
# 1                                  what is normality
# 2  what are some valuable statistical analysis op...
# 3  assessing the significance of differences in d...
# 4    the two cultures statistics vs machine learning

# %% [markdown]
# # Data Exploration

# %%
df[df.category == 'title']
# Out:
#        post_id parent_id comment_id  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            6
# ...        ...       ...        ...
# 91747   279985
# 91748   279989
# 91749   279990
# 91750   279993
# 91751   279998
#
#                                                     text category  \
# 0                          Eliciting priors from experts    title
# 1                                     What is normality?    title
# 2      What are some valuable Statistical Analysis op...    title
# 3      Assessing the significance of differences in d...    title
# 4      The Two Cultures: statistics vs. machine learn...    title
# ...                                                  ...      ...
# 91747  Long-term survivor analysis: Are usual methods...    title
# 91748  Multiple regression when one predictor is the ...    title
# 91749  Does significance level of individual coeffici...    title
# 91750  Choosing best discrete classifier in ROC analysis    title
# 91751  Probability of an exponential random variable ...    title
#
#                                               clean_text
# 0                          eliciting priors from experts
# 1                                      what is normality
# 2      what are some valuable statistical analysis op...
# 3      assessing the significance of differences in d...
# 4        the two cultures statistics vs machine learning
# ...                                                  ...
# 91747  longterm survivor analysis are usual methods s...
# 91748  multiple regression when one predictor is the ...
# 91749  does significance level of individual coeffici...
# 91750  choosing best discrete classifier in roc analysis
# 91751  probability of an exponential random variable ...
#
# [91752 rows x 6 columns]

# %%
df[df.category == 'comment']
# Out:
#         post_id parent_id comment_id  \
# 259056        1                  669
# 259057        2                  494
# 259058        3                    1
# 259059        3                   15
# 259060        3                   36
# ...         ...       ...        ...
# 812127   279994               536471
# 812128   279998               536439
# 812129   279998               536514
# 812130   279999               536802
# 812131   279999               542550
#
#                                                      text category  \
# 259056  Although I've accepted an answer, I would reco...  comment
# 259057  did you try google/ wikipedia first ? \nhttp:/...  comment
# 259058  Could be a poster child fo argumentative and s...  comment
# 259059  Maybe the focus shouldn't be on "valuable" but...  comment
# 259060  Or maybe even "How X will help you get Y done ...  comment
# ...                                                   ...      ...
# 812127  It does run, and gives very valid looking esti...  comment
# 812128  It seems to me that you are correct; the doubl...  comment
# 812129  It wouldn't be the first time a grader has mis...  comment
# 812130  The basic idea is to compare the clustering co...  comment
# 812131  As per your other question, your data does not...  comment
#
#                                                clean_text
# 259056  although ive accepted an answer i would recomm...
# 259057  did you try google wikipedia first  \nhttpenwi...
# 259058  could be a poster child fo argumentative and s...
# 259059  maybe the focus shouldnt be on valuable but ra...
# 259060  or maybe even how x will help you get y done f...
# ...                                                   ...
# 812127  it does run and gives very valid looking estim...
# 812128  it seems to me that you are correct the double...
# 812129  it wouldnt be the first time a grader has miss...
# 812130  the basic idea is to compare the clustering co...
# 812131  as per your other question your data does not ...
#
# [553076 rows x 6 columns]

# %%
df[df.category == 'post']
# Out:
#         post_id parent_id comment_id  \
# 91752         1
# 91753         2
# 91754         3
# 91755         4
# 91756         5       3.0
# ...         ...       ...        ...
# 259051   279990
# 259052   279993
# 259053   279994  279989.0
# 259054   279998
# 259055   279999  279720.0
#
#                                                      text category  \
# 91752   <p>How should I elicit prior distributions fro...     post
# 91753   <p>In many different statistical methods there...     post
# 91754   <p>What are some valuable Statistical Analysis...     post
# 91755   <p>I have two groups of data.  Each with a dif...     post
# 91756   <p>The R-project</p>\n\n<p><a href="http://www...     post
# ...                                                   ...      ...
# 259051  <p>Does significance level of individual coeff...     post
# 259052  <p>I'm trying to do ROC analysis on my dataset...     post
# 259053  <p>Theoretically, it won't work. VIF will pop ...     post
# 259054  <p>Let V have exponential(a) density, and let ...     post
# 259055  <p>In most cases it depends on what exactly yo...     post
#
#                                                clean_text
# 91752   phow should i elicit prior distributions from ...
# 91753   pin many different statistical methods there i...
# 91754   pwhat are some valuable statistical analysis o...
# 91755   pi have two groups of data  each with a differ...
# 91756   pthe rprojectp\n\npa hrefhttpwwwrprojectorghtt...
# ...                                                   ...
# 259051  pdoes significance level of individual coeffic...
# 259052  pim trying to do roc analysis on my datasetp\n...
# 259053  ptheoretically it wont work vif will pop becau...
# 259054  plet v have exponentiala density and let w be ...
# 259055  pin most cases it depends on what exactly you ...
#
# [167304 rows x 6 columns]

# %% [markdown]
# # Splitting data

# %%
training_data = df[df.category == 'title']
test_data = df[df.category != 'title']

# %% [markdown]
# # Build Ngram model

# %%
from collections import defaultdict
from collections import Counter
from nltk.util import ngrams

left_pad_symbol = "<s>"
right_pad_symbol = "</s>"

# %%
def get_ngram_sents(texts, n=2):
    """ return n-gram tuples
    """
    ngram_sents = []
    for text in texts:
        ngram_sents.extend(list(ngrams(text.split(), n)))
    return ngram_sents

def get_ngram_of_sent(sentence, n=2):
    """ return n-gram word tuples from a given sentence
    """
    return list(ngrams(sentence.split(), n))

# %%
def build_ngram_counter(ngram_sents, right_pad_symbol):
    ngram_dict = dict()
    for i, sent in enumerate(ngram_sents):
        idx = i+1
        if sent in ngram_dict:
            if idx < len(ngram_sents):
                ngram_dict[sent].update([ngram_sents[idx][1]])
            else:
                ngram_dict[sent].update([right_pad_symbol])
        else:
            ngram_dict[sent] = Counter()
            if idx < len(ngram_sents):
                ngram_dict[sent].update([ngram_sents[idx][1]])
            else:
                ngram_dict[sent].update([right_pad_symbol])
    return ngram_dict

# %%
trainig_sentences = training_data.clean_text
bigram_sents = get_ngram_sents(trainig_sentences)

# %%
bigram_counts = build_ngram_counter(bigram_sents, right_pad_symbol)

# %%
bigram_counts
# Out:
# {('eliciting', 'priors'): Counter({'from': 1, 'with': 1}),
#  ('priors', 'from'): Counter({'experts': 1, 'same': 1, 'the': 1}),
#  ('from', 'experts'): Counter({'is': 1}),
#  ('what',
#   'is'): Counter({'normality': 1,
#           'a': 247,
#           'the': 2059,
#           'your': 5,
#           'an': 62,
#           'differenceindifferences': 1,
#           'bayes': 1,
#           'aic': 1,
#           'wrong': 28,
#           'regularization': 1,
#           'it': 22,
#           'my': 8,
#           'behind': 2,
#           'this': 49,
#           'clinical': 1,
#           'going': 5,
#           'standard': 1,
#           'missing': 1,
#           'simple': 1,
#           'perplexity': 1,
#           'theta': 1,
#           'heavy': 1,
#           'sequential': 2,
#           'compound': 1,
#           'statistical': 3,
#           'best': 5,
#           'quantile': 1,
#           'conditioning': 1,
#           'determining': 1,
#           'french': 1,
#           'covxy': 2,
#           'distribution': 3,
#           'randomness': 1,
#           'meant': 28,
#           'probability': 5,
#           'empirical': 2,
#           'onestep': 1,
#           'background': 1,
#           'covariance': 1,
#           'bias': 2,
#           'percentage': 1,
#           'shannons': 1,
#           'so': 2,
#           'rank': 1,
#           'better': 5,
#           'cross': 3,
#           'mahalanobis': 1,
#           'pointwise': 1,
#           'crisp': 1,
#           'px1x2': 1,
#           'generalization': 1,
#           'absorbed': 1,
#           'iterative': 1,
#           'feature': 1,
#           'acceptable': 4,
#           'proper': 1,
#           'restricted': 1,
#           'most': 2,
#           'ey': 1,
#           'workaround': 1,
#           'difference': 10,
#           'coskewness': 1,
#           'ridge': 1,
#           'residual': 1,
#           '1p': 1,
#           'stratification': 1,
#           'geometric': 1,
#           'anova': 1,
#           'causing': 2,
#           'validity': 1,
#           'model': 1,
#           'its': 4,
#           'refdf': 1,
#           'random': 1,
#           'neglected': 1,
#           '\\rho': 1,
#           'estimated': 3,
#           'autocorrelation': 1,
#           'polychoric': 1,
#           'concordance': 1,
#           'precision': 1,
#           'content': 1,
#           'to': 2,
#           'significant': 1,
#           'permanova': 1,
#           'posterior': 1,
#           'pa': 2,
#           '\\mui': 1,
#           'assuming': 1,
#           'that': 1,
#           'cumulative': 1,
#           'tantile': 1,
#           'average': 1,
#           'bayesian': 1,
#           'asymptotic': 2,
#           'effect': 2,
#           'elastic': 1,
#           'sc4': 1,
#           'scikitlearns': 1,
#           't': 1,
#           'exactly': 3,
#           'uv': 1,
#           'correct': 3,
#           'pre': 1,
#           'linear': 1,
#           'c': 2,
#           'subsampling': 2,
#           'zy': 1,
#           'parametric': 1,
#           'poisson': 1,
#           'common': 1,
#           'function': 1,
#           'done': 1,
#           'main': 1,
#           'point': 1,
#           'parameter': 4,
#           'covariate': 1,
#           'being': 3,
#           'surrogate': 1,
#           'small': 1,
#           'there': 1,
#           'allowable': 1,
#           'instrument': 1,
#           'bayesians': 1,
#           'after': 1,
#           'penetrance': 1,
#           'gained': 1,
#           'meaning': 2,
#           'statistics': 2,
#           'prediction': 2,
#           'considered': 3,
#           'joint': 1,
#           'importance': 1,
#           'variable': 1,
#           'topological': 1,
#           'exyc': 1,
#           'gaussian': 1,
#           'functional': 2,
#           'life': 1,
#           'count': 1,
#           'required': 1,
#           'intuition': 1,
#           'bestor': 1,
#           'low': 1,
#           '\\lambdamin': 1,
#           'more': 5,
#           'data': 2,
#           'covz2z1': 1,
#           'standardizations': 1,
#           'actually': 2,
#           'deborah': 1,
#           'latent': 1,
#           'drawback': 1,
#           'pxy': 2,
#           'pab': 1,
#           'left': 1,
#           'really': 2,
#           'represented': 1,
#           'exact': 2,
#           'identification': 1,
#           'expected': 3,
#           'used': 1,
#           'matrix': 1,
#           'repeated': 1,
#           'between': 1,
#           'support': 1,
#           'rolling': 1,
#           'shrinkage': 1,
#           'obtained': 1,
#           'not': 1,
#           'appropriate': 1,
#           'misclassification': 1,
#           'pretraining': 1,
#           'bartletts': 1,
#           'reducedrank': 1,
#           'bucketization': 1,
#           'batch': 1,
#           'canonical': 1,
#           'costsensitive': 1,
#           'bootstrapping': 2,
#           'target': 1,
#           'second': 1,
#           'pat': 1,
#           '10': 1,
#           'equivalent': 1,
#           'similarities': 1,
#           'happening': 3,
#           'calibration': 1,
#           'n': 1,
#           'regressive': 1,
#           'cronbachs': 1,
#           'partial': 1,
#           'no': 1,
#           'dense': 1,
#           'suitable': 1,
#           'next': 1,
#           'popular': 1,
#           'preventing': 1,
#           'artistic': 1,
#           'forecasting': 1,
#           'crossvalidation': 2,
#           'intrinsic': 1,
#           'proportion': 1,
#           'sampling': 2,
#           'eui': 1,
#           'tophat': 1,
#           'vanishing': 1,
#           'eexyy': 1,
#           'x': 1,
#           'unit': 1,
#           'onehot': 1,
#           'statistic': 1,
#           'training': 1,
#           'pcacomponents': 1,
#           'probabilistic': 3,
#           'e': 1,
#           'variance': 2,
#           'normal': 1,
#           'printed': 1,
#           'stepwise': 1,
#           'y': 1,
#           'implied': 2,
#           'called': 1,
#           '\\nu': 1,
#           'filtration': 1,
#           'needed': 1,
#           'real': 1,
#           'simply': 1,
#           'grid': 1,
#           'usefulness': 1,
#           'svm': 1,
#           'base': 1,
#           'px\\leq': 1,
#           'in': 1,
#           'level': 1,
#           'delta': 1,
#           'least': 1,
#           'shallow': 1,
#           'likelihood': 1,
#           'k': 1,
#           'lag': 1,
#           'affine': 1,
#           'py': 1,
#           'cpktest': 1,
#           'r': 1,
#           'full': 1,
#           'taskloss': 1,
#           'predictor': 1,
#           'name': 1,
#           'f': 1,
#           'py5': 1,
#           'e\\bar': 1,
#           'auc': 2,
#           'pca': 1,
#           'robust': 1,
#           'targeted': 1,
#           'returned': 1,
#           'weaklylabeled': 1,
#           'marginal': 1,
#           'industrial': 1,
#           'connectionist': 1,
#           'technically': 1,
#           'steepest': 1,
#           'exponential': 1,
#           'single': 1,
#           'information': 1,
#           'reasonable': 1,
#           'b': 1,
#           'px1\\ge': 1,
#           'pseudomedian': 1,
#           'pabc': 1,
#           'pxx': 1,
#           'process': 1,
#           '„sample': 1,
#           'histogram': 1,
#           'rotationally': 1,
#           'hypothesis': 1,
#           'momentumlike': 1,
#           'mean': 1,
#           'good': 1,
#           '\\hat\\sigma2': 1,
#           'pvalue': 2,
#           'text': 1,
#           'high': 1,
#           'λ': 1,
#           'principal': 1,
#           'vxt': 1,
#           'zero': 1,
#           'ordinary': 1,
#           'principled': 1,
#           'skewness': 1,
#           'crosslagged': 1,
#           'demeaning': 1,
#           'maximum': 2,
#           'lm': 1,
#           'frequency': 1,
#           'descriptive': 1,
#           'geometrical': 1,
#           'qty': 1,
#           'bad': 1,
#           't12': 1,
#           'change': 1,
#           'discriminant': 1,
#           'contextual': 1,
#           'characteristic': 1,
#           'positive': 1,
#           'keeping': 1,
#           'epsilon': 1,
#           'about': 1,
#           'magnitude': 1,
#           'p': 1,
#           'regression': 1,
#           'pmpotential': 1,
#           'rest': 1,
#           'weight': 1,
#           'their': 1,
#           'central': 1,
#           'covx': 1,
#           'mu': 1,
#           'transition': 1,
#           'current': 1,
#           'hat': 1,
#           'null': 1,
#           'ex3': 1,
#           'ordered': 1,
#           'log': 1,
#           'class': 1,
#           'special': 1,
#           'granger': 1,
#           'ostrich': 1,
#           'computational': 1,
#           'logistic': 1,
#           'pj\\theta': 1,
#           '5th': 1,
#           'cramervon': 1}),
#  ('is',
#   'normality'): Counter({'are': 1,
#           'testing': 1,
#           'papers': 1,
#           'violated': 1,
#           'an': 1,
#           'important': 1,
#           'of': 1,
#           'assumption': 1}),
#  ('what',
#   'are'): Counter({'some': 94,
#           'good': 24,
#           'principal': 2,
#           'the': 352,
#           'alternatives': 3,
#           'correct': 2,
#           'common': 2,
#           'best': 2,
#           'disadvantages': 3,
#           'examples': 3,
#           'efficient': 2,
#           'average': 1,
#           'modern': 1,
#           'latest': 1,
#           'ways': 3,
#           'density': 1,
#           'other': 5,
#           'they': 5,
#           'subjective': 1,
#           'advantages': 3,
#           'similarity': 1,
#           'probabilistic': 1,
#           'chunk': 1,
#           'acceptable': 1,
#           'my': 6,
#           'rstructure': 1,
#           'utype': 1,
#           'speed': 1,
#           'possible': 4,
#           'effective': 1,
#           'finite': 1,
#           'easy': 2,
#           'ties': 1,
#           'quasi': 1,
#           'pitfalls': 1,
#           'statistical': 1,
#           'guidelines': 1,
#           'distances': 1,
#           'different': 2,
#           'typically': 1,
#           'implications': 1,
#           'hommel': 1,
#           'atomic': 1,
#           'bayesian': 1,
#           'these': 1,
#           'monte': 2,
#           'dangers': 1,
#           'general': 1,
#           'biased': 1,
#           'appropriate': 4,
#           'example': 1,
#           'assumptions': 1,
#           'kernels': 1,
#           'those': 1,
#           'polynomial': 1,
#           'their': 2,
#           'we': 1,
#           'models': 1,
#           'necessary': 1,
#           'two': 1,
#           'paralell': 1,
#           'variables': 1,
#           'characteristics': 1,
#           'machine': 1,
#           'most': 1,
#           'fringeliers': 1,
#           'conditions': 1,
#           'p': 1,
#           'residuals': 1,
#           'comments': 1,
#           'exu': 1,
#           'variable': 2,
#           'rotated': 1,
#           'allowed': 1,
#           'key': 3,
#           'bounds': 1,
#           'nbue': 1,
#           'simple': 1,
#           'pros': 1,
#           'reasons': 1,
#           'iid': 1,
#           'eigenvalues': 1,
#           'joint': 1,
#           'commonly': 2,
#           'coefficients': 1,
#           'differences': 2,
#           'real': 2,
#           'tools': 1,
#           'clustering': 1,
#           'parameters': 1,
#           'f': 1,
#           'must': 1,
#           'distribution': 1,
#           'hot': 1,
#           'marginals': 1,
#           'residual': 1,
#           'parsimonious': 1,
#           'algorithm': 1,
#           'ls': 1,
#           'online': 1,
#           'timedependent': 1,
#           'supervised': 1,
#           'considered': 1,
#           'elliptical': 1,
#           'misclassified': 1,
#           'regular': 1,
#           'methods': 1,
#           'linearly': 1,
#           'multivariable': 1,
#           'penalized': 1,
#           'periodic': 1,
#           'situations': 1,
#           'data': 1,
#           'rdx': 1,
#           'options': 1,
#           'traditional': 1,
#           'multivariate': 1,
#           'mixed': 1,
#           'shortcomings': 1}),
#  ('are',
#   'some'): Counter({'valuable': 1,
#           'good': 8,
#           'of': 12,
#           'alternatives': 3,
#           'techniques': 2,
#           'interesting': 3,
#           'ways': 3,
#           'examples': 7,
#           'useful': 3,
#           'use': 1,
#           'illustrative': 1,
#           'common': 2,
#           'distributions': 1,
#           'better': 1,
#           'nonuniform': 1,
#           'general': 1,
#           'well': 1,
#           'famous': 1,
#           'software': 1,
#           'success': 1,
#           'classification': 1,
#           'randomness': 1,
#           'real': 1,
#           'historical': 1,
#           'things': 1,
#           'adaptive': 1,
#           'simple': 2,
#           'approaches': 1,
#           'standard': 2,
#           'statistical': 4,
#           'books': 1,
#           'trends': 1,
#           'left': 1,
#           'methods': 2,
#           'fast': 2,
#           'introductions': 1,
#           'models': 1,
#           'major': 1,
#           'tests': 1,
#           'leading': 1,
#           'basic': 1,
#           'p': 1,
#           'popular': 1,
#           'reasons': 1,
#           'unstable': 1,
#           'quality': 1,
#           'important': 1,
#           'potential': 2,
#           'motivations': 1,
#           'clustering': 2,
#           'practical': 1,
#           'other': 1,
#           'entries': 1,
#           'prediction': 1,
#           'instructive': 1}),
#  ('some', 'valuable'): Counter({'statistical': 1}),
#  ('valuable', 'statistical'): Counter({'analysis': 1}),
#  ('statistical',
#   'analysis'): Counter({'open': 1,
#           'of': 27,
#           'the': 1,
#           'to': 22,
#           'project': 1,
#           'website': 1,
#           'solves': 1,
#           'for': 13,
#           'and': 3,
#           'should': 9,
#           'in': 6,
#           'krepresentatives': 1,
#           'can': 2,
#           'between': 1,
#           'using': 1,
#           'is': 6,
#           'on': 6,
#           'approach': 1,
#           'with': 3,
#           'fisher': 1,
#           'do': 1,
#           'flowchart': 1,
#           'model': 2,
#           'applied': 1,
#           'density': 1,
#           'margin': 1,
#           'that': 1,
#           'techniques': 1,
#           'without': 2,
#           'does': 1,
#           'comparing': 2,
#           'software': 1,
#           'these': 1,
#           'interval': 1,
#           'method': 1,
#           'would': 1,
#           'test': 1,
#           'repeated': 1,
#           'was': 1,
#           'replaces': 1,
#           'significance': 1,
#           'validcorrect': 1,
#           'plan': 1,
#           'did': 1,
#           'value': 1,
#           'step': 1,
#           'interpretation': 1,
#           'what': 1,
#           'options': 1,
#           'over': 1,
#           'report': 1,
#           'multicollinearity': 1,
#           'offense': 1,
#           'size': 1}),
#  ('analysis', 'open'): Counter({'source': 1}),
#  ('open',
#   'source'): Counter({'projects': 2,
#           'tools': 1,
#           'statistical': 1,
#           'textmining': 1,
#           'machine': 2,
#           'r': 1,
#           'implementation': 1,
#           'project': 1,
#           'data': 2,
#           'java': 1,
#           'software': 1,
#           'libraries': 1,
#           'mldata': 1}),
#  ('source', 'projects'): Counter({'the': 1, 'using': 1}),
#  ('assessing',
#   'the'): Counter({'significance': 1,
#           'representativeness': 1,
#           'effect': 4,
#           'accuracy': 2,
#           'ability': 1,
#           'consistency': 1,
#           'power': 1,
#           'relationship': 2,
#           'busiest': 1,
#           'need': 1,
#           'fairness': 1,
#           'validity': 1,
#           'similarity': 1,
#           'contribution': 1,
#           'fit': 2,
#           'prediction': 1,
#           'impact': 1}),
#  ('the',
#   'significance'): Counter({'of': 55,
#           'level': 4,
#           'test': 1,
#           'for': 1,
#           'between': 2,
#           'with': 1,
#           'if': 1,
#           'to': 1,
#           'in': 1}),
#  ('significance',
#   'of'): Counter({'differences': 9,
#           'said': 1,
#           'machine': 1,
#           'r2': 2,
#           'difference': 15,
#           'correlation': 6,
#           'regression': 4,
#           'predictor': 3,
#           'logistic': 3,
#           'factors': 1,
#           'components': 1,
#           'a': 50,
#           'peaks': 2,
#           'auc': 1,
#           'overlap': 2,
#           'fvalue': 1,
#           'the': 25,
#           'betas': 1,
#           'correlations': 1,
#           'slope': 3,
#           'subsets': 1,
#           'an': 2,
#           'classification': 2,
#           'individual': 2,
#           'orthonormality': 1,
#           'groups': 1,
#           'sample': 3,
#           'web': 1,
#           'population': 1,
#           'multiple': 3,
#           'different': 2,
#           'coherence': 1,
#           'skewnesskurtosis': 1,
#           'change': 3,
#           'clusters': 1,
#           'predictors': 3,
#           'male': 1,
#           'chisquare': 1,
#           'kendall': 1,
#           'coefficient': 3,
#           'increase': 1,
#           'ordered': 1,
#           'stock': 1,
#           'heavy': 1,
#           'coefficients': 1,
#           'long': 1,
#           'most': 1,
#           'adjacency': 1,
#           'pairwise': 1,
#           'infection': 1,
#           'factor': 3,
#           'unexpected': 1,
#           'smooth': 1,
#           'zscores': 1,
#           'categorical': 2,
#           'itemtoitem': 1,
#           'r': 1,
#           'feature': 1,
#           'three': 3,
#           'crosscorrelated': 1,
#           '6': 1,
#           'terms': 2,
#           'parameters': 1,
#           'parameterisation': 1,
#           'effect': 1,
#           '001': 1,
#           'each': 3,
#           'treatment': 1,
#           'binomial': 1,
#           'data': 2,
#           'modes': 1,
#           'individuals': 1,
#           'proportion': 1,
#           'regressors': 1,
#           'results': 2,
#           'significant': 1,
#           'independent': 2,
#           'ab': 1,
#           'physics': 1,
#           'mean': 2,
#           'percentage': 1,
#           'dcc': 1,
#           'biasedness': 1,
#           'chosen': 1,
#           'survey': 2,
#           'one': 1,
#           'random': 3,
#           'positive': 1,
#           'intercept': 1,
#           '1': 1,
#           'stats': 1,
#           'zero': 1,
#           'linear': 3,
#           'multi': 1,
#           'both': 1,
#           'area': 1,
#           'estimators': 1,
#           'explanatory': 1,
#           'common': 1,
#           'kalman': 1,
#           'variables': 2,
#           'assessing': 1,
#           'binary': 1,
#           'dummy': 1,
#           'two': 3,
#           'association': 1,
#           'metaanalytic': 1,
#           'any': 1,
#           'average': 2,
#           'interactions': 1,
#           'combined': 1,
#           'features': 1,
#           'incomplete': 1,
#           'spatial': 1,
#           'varibles': 1,
#           'variance': 1,
#           'median': 1,
#           'changes': 1,
#           'polynomial': 1,
#           'birth': 1,
#           'continuous': 2,
#           'overrepresentation': 1,
#           'covariance': 1,
#           'me': 1,
#           'preference': 1,
#           'spliting': 1,
#           'unknown': 1,
#           'evidence': 1,
#           'relationship': 1,
#           'latent': 1,
#           'time': 2,
#           'autocorrelation': 1,
#           'our': 1,
#           'quintile': 1,
#           '2d': 1,
#           'and': 1,
#           'inverse': 1,
#           'cumulative': 1,
#           'classifiers': 1,
#           'fixed': 1,
#           'covariates': 1,
#           '\\mathbb': 1,
#           'added': 1,
#           'variation': 1,
#           'very': 1,
#           'distribution': 1,
#           'conditional': 1,
#           'lassoridge': 1}),
#  ('of',
#   'differences'): Counter({'in': 9,
#           'between': 8,
#           'is': 2,
#           'significant': 1,
#           'of': 4,
#           'daisy': 1,
#           'to': 1}),
#  ('differences',
#   'in'): Counter({'distributions': 3,
#           'choices': 1,
#           'correlation': 2,
#           'multiple': 1,
#           'distribution': 1,
#           'baseline': 1,
#           'means': 6,
#           'age': 1,
#           'average': 1,
#           'pretreatment': 1,
#           'a': 7,
#           'populations': 1,
#           'frequencies': 3,
#           'y': 1,
#           'slope': 1,
#           'budget': 1,
#           'binary': 1,
#           'numerical': 1,
#           'differences': 3,
#           'subgroup': 1,
#           'ar1': 1,
#           'count': 2,
#           'slopes': 2,
#           'skewed': 1,
#           'the': 7,
#           'ics': 1,
#           'time': 2,
#           '3': 1,
#           'intervention': 1,
#           'kurtosis': 1,
#           'mean': 2,
#           'metaanalysis': 1,
#           'coefficients': 2,
#           'proportions': 6,
#           'categories': 1,
#           'variance': 3,
#           'power': 1,
#           '2d': 1,
#           'logistic': 1,
#           'skewness': 1,
#           'adf': 1,
#           'test': 2,
#           'biochemical': 1,
#           'an': 1,
#           'fisher': 1,
#           'correlated': 1,
#           '5': 1,
#           'coefficient': 1,
#           'causality': 1,
#           'performance': 1,
#           'gradient': 1,
#           'two': 3,
#           'rmse': 1,
#           'lsmeans': 1,
#           'ratings': 1,
#           'groups': 2,
#           'outputs': 1,
#           'discrete': 1,
#           'population': 1,
#           'recall': 1,
#           'calibration': 1,
#           'p': 1,
#           'estimates': 1,
#           'r': 5,
#           'formulas': 1,
#           'quantile': 1,
#           'interactions': 1,
#           'correlations': 1,
#           'software': 1,
#           'paired': 1,
#           'vegetation': 1,
#           'many': 1,
#           'interquartile': 1,
#           'calendar': 1,
#           'reaction': 1,
#           'auc': 1,
#           'total': 1,
#           'inferences': 1,
#           'spearman': 1,
#           'odds': 1,
#           'sample': 1,
#           'chisquared': 1,
#           'variable': 1,
#           'counts': 1,
#           'bootstrap': 1,
#           'abundance': 1,
#           'aic': 1,
#           'vif': 1,
#           'poisson': 1,
#           'linear': 1,
#           'gender': 1,
#           'ttest': 1,
#           'ranges': 1,
#           'change': 1,
#           'cost': 1,
#           'regression': 1,
#           '2': 1}),
#  ('in',
#   'distributions'): Counter({'two': 1,
#           'of': 1,
#           'three': 1,
#           'over': 1,
#           'experimental': 1}),
#  ('the',
#   'two'): Counter({'cultures': 1,
#           'densities': 1,
#           'types': 1,
#           'normal': 2,
#           'teams': 1,
#           'variable': 2,
#           'parameters': 1,
#           'groups': 3,
#           'alternative': 1,
#           'smallest': 1,
#           'weighted': 1,
#           'odds': 1,
#           'variables': 5,
#           'population': 1,
#           'visualisation': 1,
#           'confidence': 1,
#           'sample': 2,
#           'single': 1,
#           'terms': 1,
#           'of': 1,
#           'means': 1,
#           'classes': 1,
#           'time': 1,
#           'chart': 1,
#           'same': 1,
#           'processes': 1,
#           'way': 1,
#           'rows': 1,
#           'categories': 1,
#           'buses': 1,
#           'conflicting': 1,
#           'stage': 1,
#           'pvalues': 1,
#           'extremes': 1,
#           'vectors': 1,
#           'methods': 1,
#           'most': 1,
#           'asymptotes': 1,
#           'which': 1,
#           'weight': 1,
#           'is': 1,
#           'alternatives': 1,
#           'ordinary': 1,
#           'standardized': 1,
#           'balls': 1,
#           'priors': 1,
#           'there': 1,
#           'equations': 1}),
#  ('two', 'cultures'): Counter({'statistics': 1}),
#  ('cultures', 'statistics'): Counter({'vs': 1}),
#  ('statistics',
#   'vs'): Counter({'machine': 1,
#           'frequentist': 1,
#           'mathematical': 1,
#           'nhst': 1}),
#  ('vs', 'machine'): Counter({'learning': 6}),
#  ('machine',
#   'learning'): Counter({'freely': 1,
#           'for': 24,
#           'techniques': 22,
#           'up': 1,
#           'algorithms': 48,
#           'data': 6,
#           'using': 4,
#           'and': 25,
#           'cookbook': 1,
#           'software': 2,
#           'task': 2,
#           'against': 1,
#           'to': 42,
#           'less': 1,
#           'daily': 1,
#           'methods': 15,
#           'problem': 13,
#           'algorithm': 55,
#           'approach': 7,
#           'mfccs': 1,
#           'machine': 1,
#           'feature': 5,
#           'field': 1,
#           'linear': 3,
#           'application': 2,
#           'blog': 1,
#           'of': 11,
#           'implementations': 1,
#           'book': 5,
#           'deletion': 1,
#           'master': 1,
#           'on': 13,
#           'analytical': 1,
#           'classifiers': 6,
#           'predicted': 1,
#           'bot': 1,
#           'performance': 1,
#           'papers': 1,
#           'carlo': 1,
#           'regression': 7,
#           'training': 2,
#           'are': 6,
#           'curse': 1,
#           'we': 1,
#           'do': 3,
#           'input': 3,
#           'algorithmsapproaches': 1,
#           'or': 6,
#           'applications': 3,
#           'the': 8,
#           'concepts': 1,
#           'method': 2,
#           'deal': 1,
#           'with': 8,
#           'system': 3,
#           'versus': 1,
#           'constrained': 1,
#           'what': 1,
#           'model': 49,
#           'in': 11,
#           'normality': 1,
#           'competition': 1,
#           'how': 3,
#           'statistical': 1,
#           'q416': 1,
#           'pairwise': 1,
#           'adding': 1,
#           'bias': 1,
#           'value': 3,
#           'resolution': 1,
#           'can': 4,
#           'series': 2,
#           'analysis': 4,
#           'procedure': 1,
#           'technique': 8,
#           'why': 3,
#           'some': 2,
#           'from': 3,
#           'a': 14,
#           'models': 27,
#           'it': 2,
#           'probability': 1,
#           'that': 2,
#           'doesnt': 1,
#           'design': 1,
#           'classification': 6,
#           'without': 1,
#           'multinomial': 1,
#           'textbook': 2,
#           'when': 5,
#           'classifier': 4,
#           'is': 15,
#           'happen': 1,
#           'as': 1,
#           'lottery': 1,
#           'make': 1,
#           'way': 1,
#           'address': 1,
#           'references': 1,
#           'i': 4,
#           'zero': 1,
#           'alternative': 1,
#           'interaction': 1,
#           'signed': 1,
#           'really': 2,
#           'modelclassifier': 1,
#           'length': 1,
#           'features': 1,
#           'assumptions': 1,
#           'confusion': 1,
#           'inflated': 1,
#           'raw': 1,
#           'predictions': 2,
#           'about': 4,
#           'have': 1,
#           'decode': 1,
#           'academic': 1,
#           'crossvalidation': 1,
#           'cant': 1,
#           'affects': 1,
#           'prediction': 2,
#           'books': 3,
#           'not': 1,
#           'use': 1,
#           'be': 4,
#           'projects': 1,
#           'lower': 1,
#           'mathematics': 1,
#           'correlation': 2,
#           'dataset': 2,
#           'keras': 1,
#           'mass': 1,
#           'between': 3,
#           'by': 1,
#           'organisation': 1,
#           'which': 1,
#           'string': 1,
#           'project': 2,
#           'results': 1,
#           'validation': 1,
#           'mann': 1,
#           'framework': 2,
#           'methodologies': 1,
#           'error': 1,
#           'combined': 1,
#           'entropy': 1,
#           'tutorials': 1,
#           'stratified': 1,
#           'like': 2,
#           'version': 1,
#           'multiple': 1,
#           'r2': 1,
#           'priors': 1,
#           'pattern': 1,
#           'many': 1,
#           'an': 3,
#           'courses': 1,
#           'skewness': 1,
#           'testtraining': 1,
#           'library': 2,
#           'range': 1,
#           'shapes': 1,
#           'applied': 1,
#           'optimal': 1,
#           'multicollinearity': 1,
#           'called': 1,
#           'does': 4,
#           'pipeline': 2,
#           'tailed': 1,
#           'lda': 1,
#           'theory': 2,
#           'missing': 1,
#           'neural': 1,
#           'opinions': 1,
#           'experts': 1,
#           'sum': 1,
#           'find': 1,
#           'parameters': 1,
#           'numeric': 1,
#           'toolkits': 1,
#           'terms': 1,
#           'forcing': 1,
#           'detection': 1,
#           'scientist': 1,
#           'algo': 1,
#           'useful': 1,
#           'process': 1,
#           'course': 2,
#           'score': 1,
#           'accuracy': 1,
#           'tools': 1,
#           'problems': 1,
#           'scenario': 1,
#           'learn': 1,
#           'community': 3,
#           'approaches': 1,
#           'regressionclassification': 1,
#           'nested': 1,
#           'test': 1,
#           'pca': 1,
#           'variance': 1,
#           'calculated': 1,
#           'needed': 1,
#           'logit': 1,
#           'order': 1,
#           'terminology': 2,
#           'solutions': 1,
#           'inputs': 1,
#           'kernel': 1,
#           'wont': 1,
#           'subjects': 1,
#           'predicting': 1,
#           'derivative': 1,
#           'one': 1,
#           'type': 1,
#           'apply': 1,
#           'intuition': 2,
#           'time': 1,
#           'changes': 1,
#           'methodology': 2,
#           'boxplots': 1,
#           'brute': 1,
#           'etc': 1,
#           'viable': 1,
#           'create': 1,
#           'power': 1,
#           'tasks': 1,
#           'elements': 1,
#           'standard': 1,
#           'bishop': 2,
#           'distribution': 1,
#           'updating': 1,
#           'where': 1,
#           'calculating': 1,
#           'min': 1,
#           'chris': 1,
#           'random': 2,
#           'only': 1,
#           'provide': 1,
#           'characteristics': 1,
#           'text': 1,
#           'considering': 1,
#           'binary': 1,
#           'setting': 1,
#           'chapter': 1,
#           'possible': 1,
#           'vs': 1,
#           'exam': 1,
#           'tiny': 1,
#           'statement': 1,
#           'basic': 1,
#           'need': 1,
#           'representation': 1,
#           'correlated': 1,
#           'via': 1,
#           'vif': 1,
#           'mean': 1,
#           'should': 1,
#           'algorithim': 1,
#           'reproducing': 1,
#           'hypothesis': 1,
#           'estimation': 1,
#           'cross': 1,
#           'matching': 1,
#           'exercise': 1,
#           'questions': 1,
#           'related': 1,
#           'if': 1}),
#  ('locating', 'freely'): Counter({'available': 1}),
#  ('freely', 'available'): Counter({'data': 1, 'journals': 1, 'datasets': 1}),
#  ('available',
#   'data'): Counter({'samples': 1,
#           'code': 1,
#           'necessarily': 1,
#           'means': 1,
#           'proof': 1}),
#  ('data',
#   'samples'): Counter({'how': 1, 'deviation': 1, 'wilcoxon': 1, 'to': 1}),
#  ('so',
#   'how'): Counter({'many': 1,
#           'would': 1,
#           'are': 1,
#           'beta': 1,
#           'do': 4,
#           'kind': 1,
#           'should': 1,
#           'deep': 1,
#           'to': 5,
#           'can': 2,
#           'and': 1,
#           'terminology': 1}),
#  ('how',
#   'many'): Counter({'staticians': 1,
#           'times': 21,
#           'i': 1,
#           'zeroes': 1,
#           'people': 6,
#           'data': 9,
#           'lags': 8,
#           'samples': 19,
#           'copies': 1,
#           'cases': 3,
#           'of': 2,
#           'unique': 2,
#           'participants': 3,
#           'degrees': 6,
#           'letters': 1,
#           'factors': 4,
#           'random': 7,
#           'parameters': 3,
#           'games': 1,
#           'measurements': 2,
#           'observations': 10,
#           'pcs': 1,
#           'transactions': 1,
#           'counts': 2,
#           'users': 2,
#           'years': 2,
#           'toxic': 1,
#           'videos': 1,
#           'comparisons': 2,
#           'zeros': 1,
#           'failed': 1,
#           'standard': 1,
#           'min': 1,
#           'words': 1,
#           'chisquared': 1,
#           'variables': 2,
#           'groups': 2,
#           'events': 1,
#           'combinations': 2,
#           'effects': 2,
#           'percent': 1,
#           'differences': 2,
#           'normal': 1,
#           'moments': 1,
#           'markov': 1,
#           'classmates': 1,
#           'neurons': 1,
#           'trials': 2,
#           'iterations': 3,
#           'covariate': 1,
#           'experiments': 3,
#           'outcomes': 1,
#           'beds': 1,
#           'levels': 3,
#           'losing': 1,
#           'time': 1,
#           'natural': 1,
#           'backgammon': 1,
#           'sunrises': 1,
#           'ways': 5,
#           'candidate': 1,
#           'word2vec': 1,
#           'training': 1,
#           'mixtures': 1,
#           'classes': 1,
#           'missings': 1,
#           'simulations': 2,
#           'clusters': 1,
#           'such': 1,
#           'doors': 1,
#           'passengers': 1,
#           'distributions': 1,
#           'adaboost': 1,
#           'topics': 1,
#           'rare': 1,
#           'experimental': 1,
#           'americans': 1,
#           '2letter': 1,
#           'states': 1,
#           'sobol': 1,
#           'tests': 2,
#           'possible': 1,
#           'nodes': 1,
#           'missing': 1,
#           'swaps': 1,
#           'balls': 1,
#           'different': 3,
#           'components': 2,
#           'stickers': 1,
#           'digits': 2,
#           'iid': 1,
#           'features': 1,
#           'answers': 1,
#           'eligible': 1,
#           'individuals': 1,
#           'explanatory': 1,
#           'subsets': 1,
#           'degree': 1,
#           'sides': 1,
#           'dummies': 1,
#           'workspaces': 1,
#           'men': 1,
#           'replications': 2,
#           '«': 1,
#           'rolls': 1,
#           'number': 1,
#           'first': 1,
#           'subjects': 1,
#           'products': 1,
#           'unrollings': 1,
#           'decimal': 1,
#           'layers': 1,
#           'responses': 1,
#           'neighborswaps': 1,
#           'more': 1,
#           'to': 1,
#           'runs': 1,
#           'probability': 1}),
#  ('many', 'staticians'): Counter({'does': 1}),
#  ('staticians', 'does'): Counter({'it': 1}),
#  ('does',
#   'it'): Counter({'take': 9,
#           'ever': 3,
#           'tolerate': 1,
#           'mean': 142,
#           'make': 104,
#           'differ': 1,
#           'indicate': 2,
#           'exist': 2,
#           'matter': 14,
#           'have': 6,
#           'imply': 3,
#           'result': 1,
#           'signify': 2,
#           'really': 2,
#           'do': 4,
#           'calculate': 1,
#           'tell': 1,
#           'at': 1,
#           'solve': 1,
#           'makes': 4,
#           'not': 3,
#           'follow': 2,
#           'exactly': 2,
#           'need': 2,
#           'select': 1,
#           'work': 5,
#           'fail': 1,
#           'works': 2,
#           'depend': 1,
#           'means': 4,
#           'strictly': 1,
#           'alter': 1,
#           'minimize': 1,
#           'use': 2,
#           'belong': 1,
#           'converge': 1,
#           'no': 1,
#           'also': 2,
#           'count': 2,
#           'series': 1,
#           'related': 2,
#           'necessarily': 1,
#           'still': 3,
#           'affect': 3,
#           'compute': 1,
#           'represent': 1,
#           'actually': 2,
#           'hold': 1,
#           'says': 1,
#           'require': 1,
#           'bias': 1,
#           'meet': 1,
#           'rarely': 1,
#           'signifies': 1,
#           'become': 1}),
#  ('it',
#   'take'): Counter({'to': 6, 'this': 1, 'r': 1, 'two': 1, 'progressively': 1}),
#  ('take',
#   'to'): Counter({'screw': 1,
#           'achieve': 1,
#           'fill': 1,
#           'get': 1,
#           'clean': 1,
#           'capture': 1,
#           'expect': 1,
#           'undo': 1}),
#  ('to', 'screw'): Counter({'in': 1}),
#  ('screw', 'in'): Counter({'a': 1}),
#  ('in',
#   'a'): Counter({'lightbulb': 1,
#           'feedforward': 1,
#           'non': 3,
#           'data': 26,
#           'histogram': 10,
#           'series': 10,
#           'logistic': 52,
#           'two': 6,
#           'time': 77,
#           'dataframe': 2,
#           'standard': 3,
#           'mixed': 53,
#           'publication': 3,
#           'gee': 1,
#           'model': 40,
#           'market': 2,
#           'static': 1,
#           'graph': 10,
#           'multiple': 66,
#           'certain': 5,
#           'given': 25,
#           'published': 2,
#           'normalized': 1,
#           'scanned': 1,
#           'dependent': 3,
#           'group': 13,
#           'cart': 3,
#           'nonuniformly': 2,
#           'twoway': 7,
#           'irreducible': 1,
#           't': 3,
#           'kernel': 4,
#           'glmm': 18,
#           'space': 2,
#           'contingency': 7,
#           'parking': 1,
#           'database': 4,
#           'mixedeffects': 10,
#           'lattice': 1,
#           '4': 1,
#           'sample': 24,
#           'wavelet': 1,
#           'population': 16,
#           'linear': 121,
#           'factory': 1,
#           'box': 5,
#           'webbased': 1,
#           'regression': 129,
#           'table': 8,
#           'supervised': 2,
#           'hierarchical': 10,
#           'boxplot': 5,
#           'dataset': 21,
#           'generalized': 11,
#           'polygon': 2,
#           'threearm': 1,
#           'timeseries': 9,
#           'twoproportion': 1,
#           'structural': 5,
#           'fixed': 8,
#           'set': 27,
#           'negative': 7,
#           'for': 2,
#           'card': 2,
#           'poisson': 24,
#           'd': 1,
#           'forum': 1,
#           'threevalued': 1,
#           'bivariate': 4,
#           'bayesian': 30,
#           'neural': 32,
#           'moment': 1,
#           'within': 2,
#           'correlation': 6,
#           'sql': 1,
#           'glm': 25,
#           'finite': 8,
#           'range': 8,
#           'particular': 4,
#           'hand': 1,
#           'large': 11,
#           'strong': 1,
#           'simple': 37,
#           'contigency': 2,
#           'running': 1,
#           'poll': 1,
#           'nonnormally': 1,
#           'metaanalysis': 15,
#           'nonlinear': 8,
#           'research': 2,
#           'confirmatory': 1,
#           'survival': 3,
#           'process': 2,
#           'randomised': 1,
#           'loglog': 2,
#           'fully': 1,
#           'manova': 1,
#           'known': 2,
#           'different': 2,
#           'queue': 3,
#           'repeated': 18,
#           'rs': 1,
#           'normal': 11,
#           'single': 19,
#           'hospitalbased': 1,
#           'broken': 3,
#           'genetic': 2,
#           'splitplot': 1,
#           'binary': 19,
#           'survey': 7,
#           'bernoulli': 6,
#           'similar': 1,
#           'specific': 9,
#           'random': 28,
#           'family': 4,
#           'least': 3,
#           '2x2': 6,
#           'discrete': 8,
#           'discriminant': 3,
#           'sequence': 7,
#           'parameter': 3,
#           'computer': 1,
#           'gene': 2,
#           'timeline': 1,
#           'spatial': 3,
#           'logit': 9,
#           'rectangle': 1,
#           'dem': 1,
#           'lme4': 1,
#           'variable': 4,
#           'hmm': 1,
#           'nonnormal': 1,
#           'timestamp': 1,
#           'multilinear': 1,
#           'designed': 1,
#           '2x3': 2,
#           'thread': 1,
#           'mean': 1,
#           'car': 1,
#           'path': 1,
#           'numerical': 1,
#           'lottery': 4,
#           'casecontrol': 2,
#           'cfa': 2,
#           'lda': 1,
#           'spectral': 1,
#           'with': 1,
#           'pretest': 1,
#           'bimodal': 1,
#           'pca': 7,
#           'matrix': 5,
#           'moving': 5,
#           'uniform': 2,
#           'paper': 12,
#           'general': 3,
#           'feature': 2,
#           'censuslike': 1,
#           'tobit': 4,
#           'factorial': 6,
#           'grid': 3,
#           'equality': 1,
#           '30': 1,
#           'plot': 4,
#           'local': 2,
#           'larger': 3,
#           'distribution': 10,
#           'stable': 2,
#           'row': 11,
#           'multiplicative': 1,
#           'beta': 5,
#           'study': 7,
#           'lasso': 4,
#           'traffic': 1,
#           'quasiexperimental': 1,
#           'scalefree': 1,
#           'counterbalanced': 1,
#           'picture': 1,
#           'likert': 1,
#           'gaussian': 7,
#           'vector': 6,
#           'cox': 16,
#           'mixture': 6,
#           'multivariate': 15,
#           'brownian': 1,
#           'cusum': 1,
#           'ttest': 5,
#           'rolling': 1,
#           'moderated': 1,
#           'nonuniform': 1,
#           'count': 1,
#           'stochastic': 2,
#           'stock': 1,
#           'subset': 2,
#           'ucontroller': 1,
#           'test': 7,
#           'regressionclassification': 1,
#           'game': 5,
#           'gam': 3,
#           'list': 5,
#           'runs': 1,
#           'questionnaire': 3,
#           'noisy': 3,
#           'tree': 1,
#           'curvilinear': 1,
#           'pocket': 1,
#           'blocked': 1,
#           'binomial': 20,
#           'weighted': 3,
#           'computerbased': 1,
#           'crosstable': 1,
#           '2d': 6,
#           'deterministic': 2,
#           'point': 1,
#           'onesided': 1,
#           'sumrelationship': 1,
#           'scientific': 3,
#           'nested': 4,
#           'chi': 2,
#           'crossover': 5,
#           'handbook': 1,
#           'naive': 3,
#           'twostep': 2,
#           'tournament': 1,
#           'log': 4,
#           'multinomial': 5,
#           'twosample': 1,
#           '4way': 1,
#           'multiclass': 3,
#           'forward': 1,
#           'simulation': 4,
#           'growth': 1,
#           'gmm': 2,
#           'maximum': 1,
#           'small': 11,
#           'multilevel': 15,
#           'kalman': 1,
#           'highdimensional': 1,
#           'usability': 1,
#           '20': 1,
#           'crosscorrelation': 1,
#           'biased': 1,
#           'monte': 9,
#           'new': 2,
#           'svm': 2,
#           'visualization': 1,
#           'college': 1,
#           'industrial': 1,
#           'hypothesis': 5,
#           'statistical': 4,
#           'glmer': 7,
#           'url': 1,
#           'genomic': 1,
#           'power': 3,
#           'metaregression': 1,
#           'dice': 2,
#           'factor': 9,
#           'retrospective': 3,
#           'win': 1,
#           'roc': 1,
#           'rare': 1,
#           'code': 1,
#           'complex': 3,
#           'derivation': 1,
#           'normalised': 1,
#           'permutation': 3,
#           'directed': 1,
#           'statistically': 1,
#           'scatter': 5,
#           'zip': 1,
#           'panel': 9,
#           'right': 1,
#           'title': 1,
#           'very': 3,
#           'sorted': 1,
#           'sphere': 1,
#           'text': 4,
#           'barchart': 1,
#           'mixedmodel': 3,
#           'practical': 2,
#           'chisquared': 1,
#           'sparse': 1,
#           'ware': 1,
#           'field': 1,
#           'country': 1,
#           'math': 1,
#           'markov': 6,
#           'skewed': 1,
#           'conditional': 3,
#           'repeatedmeasureswithinsubjects': 1,
#           'countrys': 1,
#           'circle': 1,
#           'kmeans': 2,
#           'threeway': 1,
#           'zeroinflated': 2,
#           'round': 1,
#           'wealth': 1,
#           'chart': 1,
#           'lmer': 3,
#           'solved': 1,
#           'var': 14,
#           'categorical': 1,
#           'straight': 2,
#           'variety': 1,
#           'clinical': 6,
#           'threelevel': 1,
#           'real': 1,
#           'word': 2,
#           'system': 2,
#           'predefined': 1,
#           'machine': 6,
#           'life': 1,
#           'stepwise': 2,
#           'dynamic': 4,
#           'recent': 1,
#           'descending': 1,
#           'meta': 2,
#           'truncated': 4,
#           'phrase': 1,
#           'deep': 7,
#           'pandas': 1,
#           'bar': 2,
#           'randomized': 5,
#           'cross': 4,
#           'building': 1,
#           'part': 1,
#           'onetailed': 2,
#           'longitudinal': 7,
#           'board': 1,
#           'selected': 1,
#           'mcmc': 2,
#           'triangular': 1,
#           'loess': 3,
#           'changing': 1,
#           'classification': 8,
#           'messy': 1,
#           'seasonal': 1,
#           'fraction': 1,
#           'weird': 1,
#           'statistic': 1,
#           'convolutional': 5,
#           'largedimensional': 1,
#           'city': 3,
#           'second': 2,
#           'line': 3,
#           'direct': 1,
#           'piece': 1,
#           'ring': 1,
#           'lm': 3,
#           'learned': 1,
#           'relatively': 1,
#           'coin': 1,
#           'vecm': 2,
#           'numeric': 1,
#           'residual': 4,
#           'stata': 1,
#           'meaningful': 2,
#           'clustering': 2,
#           'boundary': 1,
#           'customer': 3,
#           'retail': 1,
#           'nonsignificant': 3,
#           'partially': 1,
#           'hypothetical': 1,
#           'batch': 2,
#           'multiarmed': 3,
#           'mcq': 1,
#           'custom': 1,
#           'circular': 1,
#           'loglevel': 2,
#           'plsda': 1,
#           'formula': 1,
#           'gamm': 1,
#           'bank': 1,
#           'clusterrandomized': 1,
#           'twofactor': 1,
#           'gibbs': 1,
#           'first': 1,
#           'screening': 1,
#           'week': 2,
#           'multidimensional': 2,
#           'bayes': 3,
#           'loan': 1,
#           'crosstabulated': 1,
#           'network': 3,
#           'significant': 1,
#           'onetomany': 1,
#           'figure': 1,
#           'employee': 1,
#           'moderatorinteraction': 1,
#           'book': 1,
#           'chi2': 1,
#           'armax': 1,
#           'coursera': 1,
#           'cubic': 1,
#           'social': 3,
#           'continuous': 4,
#           'room': 3,
#           'high': 1,
#           'forecast': 1,
#           'full': 1,
#           'mathematical': 1,
#           'differenceindifference': 2,
#           'wilcoxon': 1,
#           'case': 1,
#           'spinning': 1,
#           'cluster': 5,
#           'journal': 1,
#           'distributed': 1,
#           'arimax': 1,
#           'monotonically': 1,
#           'classic': 1,
#           'textbook': 2,
#           'name': 4,
#           'string': 3,
#           'loglinear': 2,
#           'bootstrap': 3,
#           'tripledifferences': 1,
#           'vae': 1,
#           'die': 2,
#           'gaussiandistributed': 1,
#           'multilabel': 3,
#           'fair': 2,
#           'k': 2,
#           'development': 1,
#           'mann': 1,
#           'sum': 4,
#           'boxcox': 1,
#           'working': 2,
#           'jupyter': 1,
#           'correctappropriate': 1,
#           'spreadsheet': 1,
#           'quantile': 2,
#           'statespace': 1,
#           'sigma': 1,
#           'class': 4,
#           'binom1p': 1,
#           '2way': 1,
#           '7x9': 1,
#           'prob': 1,
#           'probability': 5,
#           'metropolishastings': 2,
#           'constrained': 1,
#           'greedy': 1,
#           'logarithmic': 2,
#           'website': 1,
#           'dorm': 1,
#           'reduced': 1,
#           'garchm11': 1,
#           'randomeffects': 1,
#           'arima': 1,
#           'simulated': 1,
#           'subgroup': 1,
#           'league': 1,
#           'pile': 1,
#           'hidden': 2,
#           'frequentist': 3,
#           'tailed': 1,
#           'logtransformation': 1,
#           'hurdle': 1,
#           'matched': 2,
#           'decision': 2,
#           '3way': 1,
#           'garch': 3,
#           'goodness': 1,
#           'balanced': 2,
#           'groupby': 1,
#           'saturation': 1,
#           'multivariable': 3,
#           'decisiontree': 1,
#           '3': 4,
#           'manuscript': 1,
#           'cell': 1,
#           'cointegration': 1,
#           'quadratic': 4,
#           'triple': 1,
#           'lstm': 1,
#           'positive': 1,
#           'school': 2,
#           'gbm': 1,
#           'probit': 2,
#           'twotail': 1,
#           'not': 1,
#           'fish': 1,
#           'square': 2,
#           'controlled': 1,
#           'heteroscedastic': 2,
#           '2': 2,
#           'gp': 1,
#           'stratified': 2,
#           'classifier': 2,
#           'choice': 2,
#           'factorbyfactor': 1,
#           'big': 3,
#           'nhst': 1,
#           'stationary': 2,
#           'pseudonormal': 1,
#           'spline': 1,
#           'siamese': 1,
#           'periodic': 1,
#           'month': 2,
#           'datedaynight': 1,
#           'file': 1,
#           'streaming': 1,
#           'state': 2,
#           'gamma': 1,
#           'frequency': 1,
#           'boltzmann': 2,
#           'block': 1,
#           'same': 1,
#           'category': 1,
#           'prior': 1,
#           'team': 1,
#           'dendrogram': 1,
#           'monthly': 1,
#           'multilayer': 1,
#           'controlcase': 1,
#           'ols': 1,
#           'unique': 2,
#           'one': 2,
#           'sas': 1,
#           'repeatedmeasures': 1,
#           'twogroup': 1,
#           'carrot': 1,
#           'pomdp': 1,
#           'censored': 1,
#           'smooth': 1,
#           'twostage': 1,
#           'proof': 1,
#           'held': 1,
#           'timedependent': 1,
#           'catergoricalfactor': 1,
#           'weibull': 1,
#           'spectrum': 1,
#           'long': 1,
#           'glmmadmb': 1,
#           'biplot': 1,
#           'predictive': 2,
#           'period': 1,
#           'way': 1,
#           'medical': 2,
#           'day': 2,
#           'device': 1,
#           'nonrandom': 1,
#           '3level': 1,
#           'solution': 1,
#           'β': 1,
#           'quiz': 1,
# ...
#           'fitted': 1,
#           'ey': 1,
#           'elbo': 1,
#           'observed': 1,
#           'simple': 1,
#           'population': 1,
#           'almost': 1,
#           'functions': 1,
#           'categorical': 1,
#           'policy': 1,
#           'yij': 1,
#           'fxx1fx': 1,
#           'aurocc': 1,
#           'ad': 1,
#           'kullbackleibler': 1,
#           '\\textcovx': 1,
#           'partial': 1,
#           'test': 1,
#           '\\textexy': 1,
#           '\\frac\\overline': 1,
#           'absolute': 1,
#           'f1': 1,
#           'yx²': 1,
#           'range': 1,
#           'pa': 1,
#           'dependent': 1,
#           'mle': 1,
#           'period': 1,
#           'error': 1,
#           'timevarying': 1,
#           'its': 1,
#           'average': 1,
#           'my': 1,
#           'brownian': 1,
#           'px\\ge35': 1,
#           'kappa': 1,
#           'coefficients': 1,
#           'minimum': 1,
#           'covariates': 1,
#           'parameter': 1,
#           'drawn': 1,
#           'hx': 1,
#           '\\sigmaxy': 1,
#           '\\sin\\pi': 1,
#           '3repeated': 1,
#           '\\beta': 1}),
#  ('a',
#   'uniform'): Counter({'distribution': 36,
#           'sum': 1,
#           'by': 1,
#           'limiting': 1,
#           'random': 6,
#           'prior': 3,
#           'rv': 1,
#           'and': 1,
#           'distributed': 1,
#           'variable': 3,
#           'discrete': 2,
#           '01': 1,
#           'pvalue': 1,
#           'pdf': 1,
#           'sample': 1,
#           'between': 1,
#           'or': 1}),
#  ('uniform',
#   'distribution'): Counter({'be': 1,
#           'test': 2,
#           'is': 4,
#           'from': 4,
#           'to': 9,
#           'fgls': 1,
#           'when': 3,
#           'on': 9,
#           'generation': 1,
#           'of': 13,
#           'distribution': 3,
#           'leads': 1,
#           'over': 2,
#           'by': 2,
#           'with': 12,
#           'a': 4,
#           'in': 6,
#           'improper': 1,
#           'equation': 1,
#           'if': 1,
#           'probability': 3,
#           'regression': 2,
#           'classification': 1,
#           'size': 2,
#           'parameter': 1,
#           '11': 1,
#           'roots': 1,
#           'determine': 1,
#           'plane': 1,
#           'xi': 1,
#           'density': 1,
#           'statistical': 1,
#           'using': 2,
#           'correctly': 1,
#           'that': 2,
#           'homogeneity': 1,
#           'and': 3,
#           'between': 1,
#           'mle': 2,
#           'problems': 1,
#           'the': 4,
#           'non': 1,
#           'not': 2,
#           'can': 1,
#           'or': 2,
#           'metropolis': 1,
#           'are': 2,
#           'vector': 1,
#           'autocorrelation': 1,
#           'model': 1,
#           'have': 1,
#           'likert': 1,
#           'hazards': 1,
#           'blup': 1,
#           'mse': 1,
#           'should': 1,
#           'testing': 1,
#           'assumption': 1,
#           'looking': 1,
#           'belong': 1,
#           'ab': 1,
#           'fall': 1,
#           'do': 2,
#           'continuous': 1,
#           'as': 1,
#           'proportion': 1,
#           'measures': 1,
#           'end': 1,
#           'did': 1,
#           'nearest': 1,
#           'based': 1,
#           'degrees': 1,
#           'inside': 1,
#           'analysis': 2,
#           'qqplots': 1,
#           'u1n': 1,
#           'many': 1,
#           'confidence': 1,
#           'variable': 1,
#           'two': 2,
#           'order': 1,
#           'for': 1,
#           'logistic': 1,
#           'difficulty': 1,
#           'percentages': 1,
#           'theory': 1,
#           'an': 1,
#           'computing': 1,
#           'expectation': 1,
#           'post': 1,
#           'value': 1}),
#  ('distribution',
#   'be'): Counter({'in': 1,
#           'used': 1,
#           'larger': 1,
#           'less': 1,
#           'informative': 1,
#           'approximated': 1,
#           'personal': 1,
#           'impossible': 1,
#           'transformed': 1,
#           'interpreted': 1,
#           'discrete': 1,
#           'multimodal': 1,
#           'specification': 1,
#           'greater': 1,
#           'reconstructed': 1,
#           'known': 1,
#           'determined': 1,
#           'obtained': 1,
#           'negative': 1,
#           'over': 1}),
#  ('reliability',
#   'in'): Counter({'elicitation': 1,
#           'r': 1,
#           'extremely': 1,
#           'spss': 2,
#           'irt': 1,
#           'a': 1,
#           'rating': 1}),
#  ('in', 'elicitation'): Counter({'exercise': 1}),
#  ('elicitation', 'exercise'): Counter({'can': 1}),
#  ('find',
#   'good'): Counter({'statistics': 1,
#           'features': 2,
#           'and': 1,
#           'model': 1,
#           'smoothing': 1}),
#  ('good', 'statistics'): Counter({'quizzes': 1, 'foundation': 1}),
#  ('statistics', 'quizzes'): Counter({'is': 1}),
#  ('the', 'interpretationmeaning'): Counter({'of': 1}),
#  ('interpretationmeaning', 'of'): Counter({'confidence': 1}),
#  ('of',
#   'confidence'): Counter({'intervals': 20,
#           'interval': 27,
#           'bands': 2,
#           'in': 1,
#           'factor': 1,
#           'for': 2,
#           'of': 1,
#           'that': 1,
#           'and': 2,
#           'or': 1,
#           'from': 1}),
#  ('confidence',
#   'intervals'): Counter({'in': 21,
#           'what': 2,
#           'analysis': 2,
#           'on': 17,
#           'for': 160,
#           'the': 6,
#           'to': 18,
#           'are': 4,
#           'apply': 1,
#           'from': 16,
#           'of': 40,
#           'zero': 1,
#           'mutual': 1,
#           'generated': 1,
#           'via': 1,
#           'is': 7,
#           'and': 26,
#           'always': 1,
#           'ratings': 1,
#           'assuming': 1,
#           'after': 4,
#           'contain': 1,
#           'using': 7,
#           'smoothing': 1,
#           'it': 1,
#           'widely': 1,
#           'around': 7,
#           'when': 9,
#           'questions': 1,
#           'quantiles': 1,
#           'constant': 1,
#           'based': 2,
#           'theorem': 1,
#           'regression': 2,
#           'value': 2,
#           'exante': 1,
#           'length': 1,
#           'conditional': 1,
#           'appropriate': 2,
#           'very': 1,
#           'be': 1,
#           'intersect': 1,
#           'fisher': 1,
#           'not': 1,
#           'should': 1,
#           'intuition': 1,
#           'principal': 1,
#           'can': 3,
#           'computed': 1,
#           'plotted': 1,
#           'definitions': 1,
#           'measure': 3,
#           'generalization': 1,
#           'detect': 1,
#           'that': 3,
#           'wider': 1,
#           'meet': 1,
#           'ci': 1,
#           'i': 1,
#           'as': 4,
#           'equivalence': 1,
#           'so': 1,
#           'scaleinvariant': 1,
#           'intervals': 1,
#           'model': 1,
#           'matter': 1,
#           'significance': 1,
#           'vs': 4,
#           'hypothesis': 1,
#           'median': 1,
#           'a': 5,
#           'only': 1,
#           'with': 8,
#           'different': 1,
#           'divergence': 1,
#           'nonnormal': 1,
#           'all': 1,
#           'complexity': 1,
#           'supposed': 1,
#           'tailed': 1,
#           'equivalent': 1,
#           'over': 1,
#           'calculated': 2,
#           'do': 2,
#           'useful': 1,
#           'picks': 1,
#           'specified': 1,
#           'due': 1,
#           'statistical': 2,
#           'variance': 1,
#           'student': 1,
#           'overlap': 1,
#           'you': 2,
#           'interpretation': 1,
#           'vectors': 1,
#           'coverage': 1,
#           'symetrical': 1,
#           'regarding': 1,
#           'how': 5,
#           'cant': 1,
#           'bound': 1,
#           'false': 1,
#           'residual': 1,
#           'r': 1,
#           'standard': 2,
#           'coefficient': 1,
#           'does': 1,
#           'testing': 1,
#           'although': 1,
#           'second': 1,
#           'distribution': 1,
#           'bootstrapping': 1,
#           'which': 4,
#           'form': 1,
#           'inf': 1,
#           'categorized': 1,
#           'containing': 1,
#           'sum': 1,
#           'method': 1,
#           'variables': 1,
#           'or': 1,
#           'multilevel': 1,
#           'between': 1,
#           'transformation': 1,
#           'produced': 1,
#           'sample': 1,
#           'considered': 1,
#           'say': 1,
#           'markov': 1,
#           'nonparametric': 1,
#           'really': 1,
#           'bayes': 1,
#           'complement': 1,
#           'stata': 1,
#           'sampling': 1,
#           'coxph': 1,
#           'engineering': 1,
#           'credibility': 1,
#           'without': 1,
#           'more': 1,
#           'models': 1,
#           'mean': 1,
#           'would': 1,
#           'happens': 1,
#           'exercise': 1,
#           'skewedunbalanced': 1,
#           'adding': 1,
#           'iteratively': 1,
#           'increasing': 1,
#           'by': 1}),
#  ('intervals',
#   'in'): Counter({'misspecified': 1,
#           'rs': 1,
#           'a': 6,
#           'ridge': 1,
#           'r': 5,
#           'reality': 1,
#           'ttest': 1,
#           'the': 1,
#           'case': 1,
#           'n1': 1,
#           'anova': 1,
#           'lieu': 1,
#           'variational': 1,
#           'scikitlearn': 1,
#           '01': 1,
#           'arima': 1,
#           'archaeology': 1,
#           'classical': 1,
#           'two': 1}),
#  ('in', 'misspecified'): Counter({'models': 1}),
#  ('misspecified', 'models'): Counter({'there': 1, 'are': 1}),
#  ('a', 'radical'): Counter({'difference': 1}),
#  ('radical', 'difference'): Counter({'in': 1}),
#  ('difference',
#   'in'): Counter({'how': 3,
#           'categorization': 1,
#           'aic': 6,
#           'means': 23,
#           'users': 1,
#           'two': 4,
#           'scale': 1,
#           'time': 2,
#           'coefficients': 4,
#           'using': 1,
#           'ratios': 2,
#           'trials': 1,
#           'r': 1,
#           'differences': 15,
#           'probability': 2,
#           'signs': 1,
#           'proportions': 17,
#           'the': 7,
#           'mean': 10,
#           'calculating': 1,
#           'normal': 1,
#           'fscore': 1,
#           'bayesian': 1,
#           'preference': 1,
#           'degrees': 1,
#           'marginal': 1,
#           'survival': 1,
#           'variances': 4,
#           'regression': 1,
#           'forecasts': 1,
#           'difference': 8,
#           'bimodality': 1,
#           'hypothesis': 1,
#           'frequencies': 2,
#           'accuracy': 3,
#           'confidence': 1,
#           'pca': 2,
#           'execution': 1,
#           'group': 1,
#           'location': 2,
#           'kurtosis': 1,
#           'test': 1,
#           'average': 1,
#           'results': 3,
#           'scoring': 2,
#           'skewness': 2,
#           'populations': 2,
#           'lstm': 1,
#           'random': 1,
#           'adjusted': 1,
#           'rsquared': 2,
#           'variance': 3,
#           'significance': 1,
#           'medians': 3,
#           'an': 2,
#           'single': 1,
#           'logits': 1,
#           'probabilities': 1,
#           'proportion': 2,
#           'predicted': 1,
#           'quantile': 1,
#           'modeling': 1,
#           'aics': 1,
#           'ci': 1,
#           'one': 2,
#           'sampling': 1,
#           'importance': 1,
#           'measurements': 1,
#           'quality': 1,
#           'model': 1,
#           'center': 1,
#           'sign': 1,
#           'multiple': 1,
#           'output': 2,
#           'betas': 1,
#           'least': 1,
#           'sass': 1,
#           'a': 5,
#           'permutation': 1,
#           'estimating': 1,
#           'sample': 6,
#           'mcmc': 1,
#           'posthoc': 1,
#           'estimates': 1,
#           'interpretation': 1,
#           'log': 1,
#           'design': 1,
#           'likelihoods': 1,
#           'logistic': 1,
#           'deviance': 1,
#           'outcome': 1,
#           'correlation': 2,
#           'scaling': 1,
#           'binomial': 1,
#           'multilevel': 1,
#           'number': 3,
#           'population': 1,
#           'application': 1,
#           'data': 1,
#           'answers': 2,
#           'class': 1,
#           'change': 1,
#           'tfidf': 1,
#           'pre': 1,
#           'irr': 1,
#           'kaggletitanic': 1,
#           'totals': 1,
#           '2': 1,
#           'amount': 1,
#           'weighted': 1,
#           'compounded': 1,
#           'segments': 1,
#           'rates': 1,
#           'expected': 1,
#           'rmse': 1,
#           'variable': 1,
#           'performance': 1,
#           'success': 1,
#           'gaussians': 1,
#           'parameter': 1,
#           'median': 2,
#           'extreme': 1,
#           'sum': 1,
#           'parameters': 1,
#           'performances': 1,
#           'selecting': 1,
#           'ranked': 1,
#           'size': 1,
#           'significant': 1,
#           'partial': 1,
#           'runtime': 1,
#           'percents': 1,
#           'distributions': 1,
#           'mse': 1,
#           'dependent': 2,
#           'expressions': 1,
#           'forecast': 1,
#           'effect': 1,
#           'interpreting': 1,
#           'se': 1,
#           '3': 1,
#           'eigenvalue': 1,
#           'counts': 1,
#           'unit': 1,
#           'murder': 1,
#           'my': 1}),
#  ('in',
#   'how'): Counter({'bayesian': 1,
#           'they': 1,
#           'many': 1,
#           '\\mathrmr2': 1,
#           'to': 1}),
#  ('how', 'bayesian'): Counter({'and': 1, 'statistics': 1}),
#  ('frequentist',
#   'approaches'): Counter({'treat': 1, 'what': 1, 'to': 1, 'give': 2}),
#  ('approaches', 'treat'): Counter({'nuisance': 1}),
#  ('treat', 'nuisance'): Counter({'parameters': 1}),
#  ('nuisance',
#   'parameters'): Counter({'kolmogorovsmirnov': 1, 'by': 1, 'of': 1}),
#  ('is', 'kolmogorovsmirnov'): Counter({'test': 2}),
#  ('kolmogorovsmirnov',
#   'test'): Counter({'valid': 1,
#           'with': 4,
#           'for': 10,
#           'to': 5,
#           'on': 1,
#           'alternatives': 1,
#           'plagiarism': 1,
#           'interaction': 1,
#           'of': 2,
#           'and': 1,
#           'in': 5,
#           'the': 1,
#           'is': 3,
#           'hypothesis': 1,
#           'when': 1,
#           'strange': 1,
#           'prior': 1,
#           'using': 2,
#           'result': 2,
#           'between': 1,
#           'analysis': 2,
#           'vs': 1,
#           'known': 1,
#           'work': 1,
#           'statistic': 1,
#           'correctionadjustment': 1,
#           'rejects': 1,
#           'or': 1,
#           'analysisall': 1,
#           'reliability': 1,
#           'doesnt': 1,
#           'pvalue': 1,
#           'models': 1,
#           'whether': 1,
#           'horizontal': 1,
#           'results': 1,
#           'applying': 1,
#           'how': 1}),
#  ('test', 'valid'): Counter({'with': 1, 'for': 1, 'if': 1, 'when': 1}),
#  ('valid', 'with'): Counter({'discrete': 1, 'nonnormal': 1}),
#  ('with',
#   'discrete'): Counter({'distributions': 1,
#           'random': 1,
#           'predictors': 1,
#           'data': 1,
#           'treatment': 1,
#           'outcomes': 1,
#           'nonbinary': 1,
#           'right': 1,
#           'values': 1,
#           'and': 2,
#           'numeric': 1,
#           'prior': 1,
#           'currency': 1,
#           'variables': 1,
#           'but': 1}),
#  ('discrete',
#   'distributions'): Counter({'for': 1,
#           'with': 4,
#           'distance': 1,
#           'expectation': 1,
#           'of': 1,
#           'segmentation': 1,
#           'example': 1,
#           'are': 2,
#           'to': 1,
#           'using': 2,
#           'the': 1,
#           'that': 2,
#           'parameters': 1,
#           'pertaining': 1,
#           'highly': 1,
#           'how': 1,
#           'given': 1}),
#  ('references',
#   'for'): Counter({'survival': 1,
#           'use': 1,
#           'creating': 1,
#           'consulting': 1,
#           'weighted': 1,
#           'plotting': 1,
#           'someone': 1,
#           'the': 4,
#           'demings': 1,
#           'methods': 1,
#           'mixed': 1,
#           'generalization': 1,
#           'this': 1,
#           'computational': 1,
#           'time': 1,
#           'selffulfilling': 1,
#           'learning': 1}),
#  ('for',
#   'survival'): Counter({'analysis': 21,
#           'data': 5,
#           'functions': 1,
#           'time': 1,
#           'regression': 2,
#           'curve': 1,
#           'regressions': 1,
#           'analyses': 1,
#           'rate': 1,
#           'within': 2,
#           'modeling': 1,
#           'estimates': 1}),
#  ...}

# %% [markdown]
# ## Text generation function

# %%
def generate_text(bigram, ngram_counts):
    most_common_text, _ = ngram_counts[bigram].most_common(1).pop()
    text = ' '.join(bigram)
    return text + ' ' + most_common_text

# %%
# Run
generate_text(('some', 'valuable'), bigram_counts)
# Out:
# 'some valuable statistical'

# %%
# Example
bigram_counts[('some', 'valuable')].most_common(1).pop()
# Out:
# ('statistical', 1)

# %% [markdown]
# ## Prob

# %%
def get_prob_of_word(bigram_counter, word):
    """
    counter: bigram counter
    word: token word
    """
    prefix_count = len(bigram_counter.keys())
    word_count = bigram_counter[word]
    return word_count/prefix_count

def get_sent_prob(sent_trigrams, twogram_counts):
    sent_prob = 1
    for trigram in sent_trigrams:
        bigram = (trigram[0], trigram[1])
        bigram_counter = twogram_counts[bigram]
        word = trigram[-1]
        sent_prob *= get_prob_of_word(bigram_counter, word)
    return sent_prob

def get_word_counter(sentences):
    """ return counter from sentences
    """
    c = Counter()
    for sent in sentences:
        c.update(sent.split(' '))
    return c

def get_perplexity(sentence, twogram_counts):
    sent_trigrams = get_ngram_of_sent(sentence, 3)
    sent_prob = get_sent_prob(sent_trigrams, twogram_counts)
    n = len(sentence.split(' '))
    perplexity = np.power(1/sent_prob, 1/n)
    
    return perplexity

# %% [markdown]
# ## Laplace smoothing

# %%
corpus_counter = get_word_counter(trainig_sentences)

# %%
corpus_counter
# Out:
# Counter({'eliciting': 2,
#          'priors': 150,
#          'from': 4810,
#          'experts': 12,
#          'what': 6516,
#          'is': 12567,
#          'normality': 366,
#          'are': 3757,
#          'some': 599,
#          'valuable': 5,
#          'statistical': 1671,
#          'analysis': 3064,
#          'open': 35,
#          'source': 62,
#          'projects': 12,
#          'assessing': 94,
#          'the': 23255,
#          'significance': 881,
#          'of': 30508,
#          'differences': 503,
#          'in': 19780,
#          'distributions': 1236,
#          'two': 3759,
#          'cultures': 1,
#          'statistics': 1047,
#          'vs': 2009,
#          'machine': 877,
#          'learning': 1620,
#          'locating': 3,
#          'freely': 4,
#          'available': 96,
#          'data': 9208,
#          'samples': 991,
#          'so': 281,
#          'how': 13470,
#          'many': 627,
#          'staticians': 1,
#          'does': 3202,
#          'it': 2347,
#          'take': 152,
#          'to': 21783,
#          'screw': 2,
#          'a': 23413,
#          'lightbulb': 1,
#          'under': 324,
#          'conditions': 161,
#          'should': 1527,
#          'likert': 222,
#          'scales': 104,
#          'be': 2201,
#          'used': 759,
#          'as': 1794,
#          'ordinal': 491,
#          'or': 3176,
#          'interval': 1259,
#          'multivariate': 954,
#          'interpolation': 50,
#          'approaches': 97,
#          'forecasting': 522,
#          'demographic': 14,
#          'census': 20,
#          'bayesian': 1255,
#          'and': 13121,
#          'frequentist': 134,
#          'reasoning': 27,
#          'plain': 26,
#          'english': 28,
#          'finding': 782,
#          'pdf': 400,
#          'given': 1212,
#          'cdf': 318,
#          'tools': 39,
#          'for': 16677,
#          'modeling': 452,
#          'financial': 35,
#          'time': 3301,
#          'series': 2425,
#          'standard': 1767,
#          'deviation': 822,
#          'testing': 1304,
#          'random': 3951,
#          'variate': 16,
#          'generation': 61,
#          'algorithms': 317,
#          'meaning': 268,
#          'p': 421,
#          'values': 1919,
#          't': 385,
#          'tests': 656,
#          'r': 5005,
#          'packages': 61,
#          'seasonality': 155,
#          'examples': 181,
#          'teaching': 26,
#          'correlation': 2179,
#          'not': 2220,
#          'mean': 2854,
#          'causation': 46,
#          'pseudorandom': 18,
#          'number': 1550,
#          'explain': 225,
#          'visualization': 105,
#          'clustering': 992,
#          'large': 753,
#          'heavytailed': 17,
#          'dataset': 834,
#          'pca': 1047,
#          'on': 5072,
#          'covariance': 851,
#          'why': 3681,
#          'do': 3413,
#          'us': 60,
#          'uk': 3,
#          'schools': 8,
#          'teach': 10,
#          'different': 2236,
#          'methods': 596,
#          'calculating': 746,
#          'can': 3950,
#          'someone': 107,
#          'please': 71,
#          'backpropagation': 76,
#          'algorithm': 839,
#          'you': 912,
#          'find': 1242,
#          'most': 358,
#          'useful': 140,
#          'your': 104,
#          'daily': 122,
#          'work': 346,
#          'where': 713,
#          'i': 4985,
#          'tutorials': 12,
#          'with': 11038,
#          'various': 60,
#          'implementations': 13,
#          'robust': 251,
#          'nonparametric': 333,
#          'estimation': 931,
#          'hazardsurvival': 2,
#          'functions': 396,
#          'based': 907,
#          'low': 335,
#          'count': 414,
#          'difference': 1935,
#          'expected': 706,
#          'between': 3875,
#          'garch': 158,
#          'asymmetric': 50,
#          'volatility': 64,
#          'forecasts': 96,
#          'good': 559,
#          'basic': 171,
#          'use': 2940,
#          'favorite': 7,
#          'blog': 5,
#          'power': 550,
#          'holms': 1,
#          'multiple': 2558,
#          'comparison': 420,
#          'compared': 97,
#          'others': 69,
#          'frameworks': 5,
#          'method': 998,
#          'selection': 878,
#          'blogs': 1,
#          'would': 449,
#          'recommend': 25,
#          'square': 456,
#          'instead': 321,
#          'taking': 114,
#          'absolute': 189,
#          'value': 1828,
#          'best': 901,
#          'introductory': 30,
#          'textbook': 57,
#          'clojure': 1,
#          'versus': 268,
#          'advantages': 56,
#          'disadvantages': 25,
#          'compute': 473,
#          'running': 159,
#          'median': 388,
#          'free': 50,
#          'resources': 58,
#          'one': 1884,
#          'regression': 10265,
#          'predict': 482,
#          'principal': 373,
#          'component': 335,
#          'pc': 39,
#          'several': 241,
#          'other': 567,
#          'pcs': 20,
#          'there': 1507,
#          'deal': 313,
#          'label': 60,
#          'switching': 23,
#          'problem': 1163,
#          'mcmc': 295,
#          'mixture': 360,
#          'models': 2056,
#          'markov': 428,
#          'chain': 214,
#          'monte': 285,
#          'carlo': 285,
#          'layperson': 4,
#          'textbooks': 22,
#          'counts': 145,
#          '': 5629,
#          '20': 33,
#          'outliers': 358,
#          'dealt': 10,
#          'linear': 3871,
#          'choose': 379,
#          'hidden': 177,
#          'layers': 43,
#          'nodes': 44,
#          'feedforward': 19,
#          'neural': 1133,
#          'network': 939,
#          'could': 164,
#          'applying': 167,
#          'movielens': 1,
#          'cross': 549,
#          'tabulation': 3,
#          'categorical': 1185,
#          'variables': 4608,
#          'recommended': 40,
#          'techniques': 177,
#          'mining': 108,
#          'tell': 144,
#          'whether': 387,
#          'pattern': 167,
#          'extracted': 21,
#          'meaningful': 75,
#          'visualizing': 90,
#          'multidimensional': 107,
#          'group': 547,
#          'five': 28,
#          'point': 490,
#          'item': 112,
#          'discrete': 534,
#          'continuous': 1013,
#          'way': 889,
#          'identify': 172,
#          'scores': 361,
#          'intro': 8,
#          'an': 3124,
#          'md': 2,
#          'libraries': 16,
#          'standalone': 3,
#          'applications': 52,
#          'using': 3962,
#          'analyzepredict': 1,
#          'violent': 1,
#          'behavior': 69,
#          'variance': 2278,
#          'components': 294,
#          'easiest': 6,
#          'create': 244,
#          'publicationquality': 2,
#          'plots': 222,
#          'linux': 2,
#          'calculate': 1439,
#          'if': 2028,
#          'degree': 107,
#          'overlap': 60,
#          'lists': 27,
#          'significant': 906,
#          'population': 762,
#          'sample': 3052,
#          'effect': 1332,
#          'order': 528,
#          'observations': 510,
#          'non': 323,
#          'hierarchical': 271,
#          'cluster': 433,
#          'differencerelationship': 1,
#          'moments': 195,
#          'gmm': 54,
#          'stata': 254,
#          'when': 3847,
#          'appropriate': 538,
#          'log': 543,
#          'independent': 1356,
#          'variable': 4156,
#          'actual': 91,
#          'gentle': 1,
#          'boosting': 118,
#          'differ': 103,
#          'adaboost': 46,
#          'about': 1037,
#          'estimating': 591,
#          'huge': 78,
#          'readonce': 1,
#          'set': 1364,
#          'trinity': 1,
#          'maximum': 731,
#          'likelihood': 1190,
#          'faced': 1,
#          'contradicting': 19,
#          'conclusions': 33,
#          'single': 413,
#          'influential': 17,
#          'book': 182,
#          'every': 100,
#          'statistician': 15,
#          'read': 57,
#          'key': 14,
#          'concepts': 25,
#          'that': 2720,
#          'relate': 41,
#          'monty': 12,
#          'hall': 11,
#          'our': 39,
#          'intuition': 219,
#          'fail': 62,
#          'proving': 119,
#          'randomness': 64,
#          'numbers': 385,
#          'something': 133,
#          'happened': 14,
#          'which': 1590,
#          'monitors': 1,
#          'over': 685,
#          'motivation': 23,
#          'kolmogorov': 29,
#          'distance': 607,
#          'isnt': 74,
#          'ransac': 3,
#          'widely': 15,
#          'nonstatistician': 5,
#          'scientists': 9,
#          'cartoon': 4,
#          'always': 289,
#          'report': 167,
#          'white': 86,
#          'errors': 560,
#          'mathematical': 134,
#          'videos': 5,
#          'negative': 814,
#          'aicc': 28,
#          'corrected': 20,
#          'akaike': 21,
#          'information': 500,
#          'criterion': 101,
#          'procedure': 128,
#          'binary': 1005,
#          'classification': 1104,
#          'dubious': 1,
#          'signal': 94,
#          'processing': 42,
#          'principles': 13,
#          'trend': 276,
#          'sas': 155,
#          'copy': 6,
#          'paste': 3,
#          'output': 696,
#          'window': 54,
#          'checking': 107,
#          'convergence': 336,
#          'unsupervised': 85,
#          'supervised': 97,
#          'semisupervised': 21,
#          'ways': 106,
#          'show': 387,
#          'analytical': 39,
#          'equivalent': 228,
#          'imply': 110,
#          'ever': 84,
#          'make': 487,
#          'sense': 237,
#          'treat': 77,
#          'anova': 1231,
#          'taught': 6,
#          'research': 109,
#          'methodology': 51,
#          'prediction': 933,
#          'instrumental': 68,
#          'differenceindifferences': 33,
#          'graphical': 79,
#          'structural': 126,
#          'equation': 458,
#          'understand': 233,
#          'convolutional': 121,
#          'deep': 301,
#          'belief': 27,
#          'audio': 17,
#          'posthocs': 3,
#          'within': 334,
#          'subjects': 123,
#          'any': 580,
#          'reason': 81,
#          'prefer': 21,
#          'aic': 305,
#          'bic': 100,
#          'baumwelch': 5,
#          'viterbi': 7,
#          'training': 771,
#          'extent': 21,
#          'we': 1029,
#          'call': 76,
#          'geometric': 145,
#          'distribution': 6743,
#          'density': 758,
#          'em': 129,
#          'intuitive': 119,
#          'explanation': 194,
#          'like': 224,
#          'discriminative': 15,
#          'heuristics': 7,
#          'optimizing': 54,
#          'νsvm': 1,
#          'predicted': 245,
#          'discriminant': 159,
#          'imperfect': 8,
#          'empirically': 11,
#          'demonstrate': 20,
#          'crossvalidation': 297,
#          'followed': 21,
#          'by': 1507,
#          'rotation': 60,
#          'such': 143,
#          'varimax': 19,
#          'still': 143,
#          'place': 30,
#          'survey': 293,
#          'results': 1268,
#          'convey': 2,
#          'beauty': 3,
#          'central': 214,
#          'limit': 275,
#          'theorem': 373,
#          'aggregate': 67,
#          'analyze': 187,
#          'books': 75,
#          'introduction': 41,
#          'automating': 6,
#          'texts': 11,
#          'bayes': 444,
#          'all': 654,
#          'lies': 17,
#          'damn': 1,
#          'anonymization': 1,
#          'software': 123,
#          'famous': 12,
#          'quotations': 1,
#          'types': 130,
#          'normal': 1912,
#          'monotonic': 28,
#          'transformations': 84,
#          'logmean': 1,
#          'normalization': 190,
#          'optimal': 297,
#          'bins': 55,
#          'histogram': 162,
#          'never': 36,
#          'functional': 70,
#          'high': 514,
#          'dimensional': 134,
#          'suggestions': 49,
#          'making': 111,
#          'code': 165,
#          'processors': 1,
#          'looking': 173,
#          'formal': 41,
#          'but': 902,
#          'answer': 86,
#          'comparing': 1073,
#          'paired': 331,
#          'fishersnedecor': 1,
#          'model': 7581,
#          'test': 5513,
#          'gwo': 1,
#          'lasso': 440,
#          'ridge': 224,
#          'hypothesis': 964,
#          'correction': 240,
#          'benjaminihochberg': 8,
#          'pvalues': 372,
#          'qvalues': 7,
#          'correct': 620,
#          'spelling': 4,
#          'capitalization': 1,
#          'italicization': 1,
#          'hyphenation': 1,
#          'pvalue': 627,
#          'econometrics': 52,
#          'vecm': 58,
#          'cointegration': 101,
#          'vectors': 275,
#          'validation': 645,
#          'very': 398,
#          'dimension': 135,
#          'select': 192,
#          'expansion': 34,
#          'function': 2649,
#          'fundamental': 21,
#          'idea': 54,
#          'parameters': 904,
#          'question': 962,
#          'regarding': 180,
#          'stdev': 13,
#          'reference': 204,
#          'category': 82,
#          'realtime': 7,
#          'streaming': 13,
#          'separating': 19,
#          'populations': 119,
#          'relationships': 90,
#          'determine': 672,
#          'three': 280,
#          'statistically': 295,
#          'than': 1336,
#          'ten': 8,
#          '1000000': 3,
#          'podcasts': 1,
#          'measurement': 212,
#          'level': 449,
#          'percentile': 106,
#          'probability': 3122,
#          'interpretations': 13,
#          'yates': 8,
#          'continuity': 22,
#          'only': 711,
#          '2x2': 72,
#          'get': 634,
#          'stop': 31,
#          'autocompleting': 1,
#          'my': 1388,
#          'quotesparens': 1,
#          'logistic': 2446,
#          'solved': 27,
#          'closed': 72,
#          'form': 287,
#          'reduce': 128,
#          'items': 225,
#          'multiitem': 2,
#          'scale': 526,
#          'each': 590,
#          'requires': 15,
#          'ranking': 116,
#          'four': 67,
#          'response': 599,
#          'options': 69,
#          'freelance': 1,
#          'opportunity': 2,
#          'points': 582,
#          'spearmans': 62,
#          'coefficient': 874,
#          'usable': 3,
#          'compare': 1058,
#          'calculated': 164,
#          'uniform': 431,
#          'reliability': 136,
#          'elicitation': 3,
#          'exercise': 54,
#          'quizzes': 2,
#          'interpretationmeaning': 1,
#          'confidence': 1677,
#          'intervals': 723,
#          'misspecified': 5,
#          'radical': 1,
#          'nuisance': 10,
#          'kolmogorovsmirnov': 104,
#          'valid': 276,
#          'references': 77,
#          'survival': 426,
#          'orthogonal': 110,
#          'parametrization': 9,
#          'approximating': 49,
#          'nonnormal': 221,
#          'bernoullilike': 3,
#          'tonga': 1,
#          'rank': 326,
#          'approximation': 200,
#          'natural': 90,
#          'gradient': 414,
#          'le': 1,
#          'roux': 1,
#          'et': 28,
#          'al': 20,
#          '2007': 1,
#          'handle': 209,
#          'has': 575,
#          'been': 71,
#          'converted': 12,
#          'rate': 476,
#          'represent': 110,
#          'unbounded': 13,
#          '0': 541,
#          '1': 906,
#          'percentage': 226,
#          'change': 561,
#          'earnings': 2,
#          'produced': 29,
#          'changed': 41,
#          'price': 106,
#          'reasons': 41,
#          'besides': 21,
#          'build': 137,
#          'chisquared': 269,
#          'simple': 681,
#          'online': 127,
#          'outlier': 176,
#          'detection': 291,
#          'generic': 17,
#          'multicollinearity': 216,
#          'put': 23,
#          'beforeafter': 9,
#          'session': 9,
#          'havent': 3,
#          'resistant': 3,
#          'replaced': 3,
#          'classical': 44,
#          'alternative': 268,
#          'graphics': 15,
#          'bar': 59,
#          'practical': 80,
#          'thoughts': 8,
#          'explanatory': 165,
#          'predictive': 349,
#          'apply': 242,
#          'pareto': 69,
#          'tail': 115,
#          'truncated': 149,
#          'twosample': 65,
#          'ttest': 759,
#          'weighted': 400,
#          'period': 112,
#          'timeseries': 305,
#          'heterogeneity': 44,
#          'studies': 122,
#          'roc': 252,
#          'curves': 149,
#          'traditional': 21,
#          'inference': 361,
#          'wouldnt': 2,
#          'nontrivial': 5,
#          'bound': 187,
#          'e\\expz2': 1,
#          'z': 212,
#          '\\sim': 106,
#          '\\rm': 7,
#          'binn': 2,
#          'n\\beta': 1,
#          '\\beta': 66,
#          '\\in': 26,
#          '01': 100,
#          'cheat': 4,
#          'sheet': 8,
#          'input': 255,
#          'jaccard': 21,
#          'itemitem': 1,
#          'similarity': 289,
#          'calculation': 376,
#          'speed': 58,
#          'up': 264,
#          'this': 1861,
#          'without': 601,
#          'multicore': 5,
#          'sequential': 101,
#          'adaptive': 47,
#          'process': 887,
#          'fitting': 639,
#          'fixed': 524,
#          'exponential': 581,
#          'relationship': 507,
#          'categories': 198,
#          'repeatedmeasures': 39,
#          'multiway': 5,
#          'svd': 113,
#          'dimensionality': 171,
#          'reduction': 213,
#          'length': 173,
#          'these': 269,
#          'similar': 255,
#          'incidence': 43,
#          'differenceratio': 1,
#          'case': 336,
#          'experimental': 172,
#          'design': 532,
#          'obtain': 167,
#          'possible': 704,
#          'combinations': 97,
#          'histograms': 62,
#          'barcharts': 1,
#          'essential': 6,
#          'reads': 1,
#          'people': 154,
#          'interested': 17,
#          'actuary': 2,
#          'actuarial': 3,
#          'science': 43,
#          'extending': 8,
#          'birthday': 32,
#          'paradox': 71,
#          'more': 760,
#          '2': 777,
#          'figure': 52,
#          'out': 441,
#          'kind': 159,
#          'represents': 18,
#          'ping': 2,
#          'times': 256,
#          'scalar': 31,
#          'jokes': 1,
#          'around': 106,
#          'numerical': 156,
#          'overflow': 9,
#          'card': 47,
#          'game': 101,
#          'sampling': 982,
#          'according': 77,
#          'version': 85,
#          'hotelling': 9,
#          't2': 17,
#          'variability': 79,
#          'suggest': 35,
#          'compression': 10,
#          'handling': 82,
#          'incompletemissing': 1,
#          'odds': 307,
#          'ratios': 193,
#          'consequences': 35,
#          'improper': 32,
#          'link': 179,
#          'n': 551,
#          'forced': 9,
#          'choice': 196,
#          'procedures': 22,
#          'eg': 106,
#          '2afc': 2,
#          'mixed': 1152,
#          'custom': 59,
#          'risk': 192,
#          'dice': 104,
#          'example': 371,
#          '2nd': 21,
#          'stationary': 284,
#          'strictly': 46,
#          'residuals': 634,
#          'stochastic': 229,
#          '1st': 22,
#          'round': 14,
#          'transform': 255,
#          'nonnegative': 75,
#          'including': 139,
#          'zeros': 110,
#          'determination': 78,
#          'r2': 333,
#          'have': 1199,
#          'fully': 54,
#          'grasped': 1,
#          'interpretation': 799,
#          'unknown': 255,
#          'type': 478,
#          'transfer': 37,
#          'primer': 2,
#          'estimator': 771,
#          'efficiency': 57,
#          'directly': 43,
#          'csv': 9,
#          'columns': 84,
#          'implementation': 156,
#          'andersondarling': 20,
#          'rv': 114,
#          '\\chink': 1,
#          'resourcesmethods': 1,
#          'exist': 109,
#          'testingvalidation': 1,
#          'evaluation': 141,
#          'binomial': 1007,
#          'business': 21,
#          'newbie': 11,
#          'tosses': 25,
#          'coin': 168,
#          'whats': 401,
#          'proportion': 348,
#          'postfit': 1,
#          'exact': 240,
#          'relative': 206,
#          'supremum': 4,
#          'brownian': 54,
#          'bridge': 12,
#          'kolmogorov–smirnov': 15,
#          'frequencies': 80,
#          'conditional': 871,
#          'events': 345,
#          'factor': 882,
#          'coefficients': 1027,
#          'flip': 28,
#          'sign': 134,
#          'after': 671,
#          'predictors': 500,
#          '060': 1,
#          'increase': 182,
#          '60': 10,
#          'likely': 69,
#          'python': 274,
#          'workbench': 3,
#          'remember': 5,
#          'definitions': 37,
#          'ii': 49,
#          'working': 90,
#          'statisticians': 28,
#          'care': 37,
#          'geometry': 11,
#          'define': 111,
#          'distances': 85,
#          'volumes…useful': 1,
#          'noncentral': 36,
#          'zscore': 76,
#          'at': 800,
#          'ztable': 4,
#          'groups': 862,
#          'arent': 44,
#          'their': 221,
#          'assumptions': 289,
#          'small': 601,
#          'intraclass': 25,
#          'aggregation': 35,
#          'fit': 1053,
#          'while': 198,
#          'incorporating': 29,
#          'censoring': 46,
#          '2sample': 12,
#          'univariate': 150,
#          'fisher': 152,
#          'surface': 35,
#          'area': 125,
#          'typical': 32,
#          'just': 166,
#          'installed': 1,
#          'latest': 6,
#          'chernofflike': 1,
#          'largest': 47,
#          'allowed': 31,
#          'tangency': 2,
#          'portfolio': 29,
#          'variation': 205,
#          'weights': 362,
#          'draw': 114,
#          'probable': 14,
#          'outcome': 360,
#          'videoaudio': 1,
#          'material': 11,
#          'getting': 247,
#          'into': 569,
#          'logisticregressions': 1,
#          'exportformat': 1,
#          'pairwisettest': 3,
#          'latex': 9,
#          'summary': 161,
#          'unique': 84,
#          'factors': 363,
#          'dataframe': 28,
#          'cartesian': 6,
#          'plot': 937,
#          'alternatives': 119,
#          'broken': 9,
#          'axes': 30,
#          'precision': 176,
#          'recall': 92,
#          'edge': 18,
#          'cases': 134,
#          'shall': 16,
#          'trust': 29,
#          'nonfull': 1,
#          'slope': 243,
#          'full': 110,
#          'start': 69,
#          'keywords': 3,
#          'bibliography': 2,
#          'detect': 185,
#          'correlations': 277,
#          'unbiased': 234,
#          'matrix': 1465,
#          'multiply': 47,
#          'censored': 112,
#          'bootstrap': 324,
#          'glm': 698,
#          'effects': 1154,
#          'fishers': 136,
#          'contingency': 120,
#          'tables': 89,
#          'larger': 159,
#          'perform': 360,
#          'students': 93,
#          'having': 187,
#          'size': 1466,
#          'average': 625,
#          'known': 328,
#          'genetic': 44,
#          'experiment': 255,
#          'needed': 189,
#          'repeated': 634,
#          'pros': 24,
#          'cons': 28,
#          'logrank': 16,
#          'mantelhaenszel': 4,
#          'computing': 294,
#          'hazard': 173,
#          'ratio': 743,
#          'rating': 72,
#          'system': 194,
#          'cohens': 80,
#          'd': 109,
#          'hedges': 8,
#          'g': 33,
#          'metrics': 111,
#          'null': 352,
#          'same': 1155,
#          'skew': 58,
#          'application': 81,
#          'clinical': 58,
#          'summarize': 22,
#          'runs': 44,
#          'color': 31,
#          'deck': 22,
#          'cards': 42,
#          'jack': 3,
#          'clumsy': 1,
#          'parametric': 197,
#          'reconstruction': 24,
#          'contours': 11,
#          'quick': 17,
#          'rescaling': 23,
#          'weatherman': 1,
#          'accurate': 74,
#          'revolutions': 1,
#          'last': 54,
#          '50': 61,
#          'years': 93,
#          'determining': 291,
#          'benchmark': 11,
#          'conferences': 2,
#          'invariance': 40,
#          'cause': 86,
#          'loss': 449,
#          'newmans': 1,
#          'modularity': 1,
#          'graphs': 78,
#          'accepted': 17,
#          'definition': 251,
#          'plane': 23,
#          'higher': 212,
#          'ordered': 136,
#          'spaces': 37,
#          'name': 265,
#          'noisy': 94,
#          'sequences': 78,
#          'estimate': 1056,
#          'them': 169,
#          'being': 207,
#          'instances': 50,
#          'identical': 77,
#          '3': 327,
#          'levels': 315,
#          'treatment': 266,
#          'metaanalysis': 247,
#          'kernel': 444,
#          'bandwidth': 44,
#          'journal': 11,
#          'turnaround': 1,
#          'familywise': 4,
#          'multilevelhierarchical': 2,
#          'problematic': 27,
#          'control': 337,
#          'nonindependent': 32,
#          'covariates': 209,
#          'observational': 40,
#          'ie': 68,
#          'nonrandomized': 2,
#          'study': 357,
#          'decide': 86,
#          'span': 7,
#          'loess': 40,
#          'datamining': 7,
#          'measures': 629,
#          'publication': 27,
#          'importance': 264,
#          'plotting': 165,
#          'booksarticlesguides': 1,
#          'enter': 18,
#          'analytics': 20,
#          'st': 11,
#          'dev': 14,
#          'gaussian': 955,
#          'curve': 498,
#          'spike': 18,
#          'biplots': 4,
#          'mle': 385,
#          'short': 84,
#          'assist': 4,
#          'lecture': 6,
#          'numerically': 32,
#          'approximate': 143,
#          'beta': 432,
#          ...})

# %%
def get_laplace_smoothing(bigram_counter, prefix, corpus_counter, delta=0.001):
    prefix_count = len(bigram_counter.keys())
    token_count = bigram_counter[prefix]
    N = len(corpus_counter.keys())
    laplace_score = (token_count + delta)/(prefix_count + (delta * N))

    return laplace_score
